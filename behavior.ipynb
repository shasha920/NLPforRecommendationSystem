# %%
import pandas as pd
import numpy as np
import random

# %%
df1=pd.read_table('traces.tsv')
df1
# Out:
#          auction_id             bid_time  bid_ct  bid_number      bid_user  \
# 0            222387  2009-10-04 12:33:26   19913           1    Becker1990
# 1            222387  2009-10-04 14:28:14   13029           2      Gaynor66
# 2            222387  2009-10-04 14:44:08   12079           3     Jostrem16
# 3            222387  2009-10-04 17:14:26    3071           4     Clubfan78
# 4            222387  2009-10-04 17:36:06    1773           5    Momstired2
# ...             ...                  ...     ...         ...           ...
# 2049967      259070  2009-12-12 21:29:30      15         517    Blaufish83
# 2049968      259070  2009-12-12 21:29:30      15         518      Solwicca
# 2049969      259070  2009-12-12 21:29:30      15         519      Jaden248
# 2049970      259070  2009-12-12 21:29:30      15         520       Orion29
# 2049971      259070  2009-12-12 21:29:34      15         521  Schonmir1500
#
#          bid_butler  bid_cp  bid_user_secs_added  bid_butler_secs_added  \
# 0                 0      12                    0                      0
# 1                 0      24                    4                      0
# 2                 0      36                    4                      0
# 3                 0      48                   10                      0
# 4                 0      60                    2                      0
# ...             ...     ...                  ...                    ...
# 2049967           0    3102                   14                      0
# 2049968           0    3108                   14                      0
# 2049969           0    3114                   14                      0
# 2049970           0    3120                   14                      0
# 2049971           0    3126                    4                      0
#
#          bid_infered  bid_group  bid_final
# 0                  0          0          0
# 1                  0          1          0
# 2                  0          2          0
# 3                  0          3          0
# 4                  0          4          0
# ...              ...        ...        ...
# 2049967            1        374          0
# 2049968            1        374          0
# 2049969            1        374          0
# 2049970            0        374          0
# 2049971            0        375          1
#
# [2049972 rows x 12 columns]

# %%
df2=df1.drop_duplicates(subset=['auction_id','bid_user']).groupby('bid_user').size().sort_values(ascending=False).reset_index()
df2.columns =['bid_user', 'counts']
df2
# Out:
#          bid_user  counts
# 0      Lillyblitz     258
# 1         Npr1967     225
# 2      Drodenbeck     214
# 3       Zwerg1953     191
# 4           Varis     191
# ...           ...     ...
# 60532   Keebler87       1
# 60533       Kedii       1
# 60534     Kebo178       1
# 60535    Keber314       1
# 60536      zzindy       1
#
# [60537 rows x 2 columns]

# %%
df2=df2[df2['counts']>=2]
df2
# Out:
#          bid_user  counts
# 0      Lillyblitz     258
# 1         Npr1967     225
# 2      Drodenbeck     214
# 3       Zwerg1953     191
# 4           Varis     191
# ...           ...     ...
# 37244      Dansgr       2
# 37245     Julsche       2
# 37246  Topdolly75       2
# 37247   Topazlady       2
# 37248      Sinopa       2
#
# [37249 rows x 2 columns]

# %%
df3=df1[df1['bid_user'].isin(df2['bid_user'].tolist())]
df3
# Out:
#          auction_id             bid_time  bid_ct  bid_number      bid_user  \
# 0            222387  2009-10-04 12:33:26   19913           1    Becker1990
# 1            222387  2009-10-04 14:28:14   13029           2      Gaynor66
# 2            222387  2009-10-04 14:44:08   12079           3     Jostrem16
# 3            222387  2009-10-04 17:14:26    3071           4     Clubfan78
# 4            222387  2009-10-04 17:36:06    1773           5    Momstired2
# ...             ...                  ...     ...         ...           ...
# 2049967      259070  2009-12-12 21:29:30      15         517    Blaufish83
# 2049968      259070  2009-12-12 21:29:30      15         518      Solwicca
# 2049969      259070  2009-12-12 21:29:30      15         519      Jaden248
# 2049970      259070  2009-12-12 21:29:30      15         520       Orion29
# 2049971      259070  2009-12-12 21:29:34      15         521  Schonmir1500
#
#          bid_butler  bid_cp  bid_user_secs_added  bid_butler_secs_added  \
# 0                 0      12                    0                      0
# 1                 0      24                    4                      0
# 2                 0      36                    4                      0
# 3                 0      48                   10                      0
# 4                 0      60                    2                      0
# ...             ...     ...                  ...                    ...
# 2049967           0    3102                   14                      0
# 2049968           0    3108                   14                      0
# 2049969           0    3114                   14                      0
# 2049970           0    3120                   14                      0
# 2049971           0    3126                    4                      0
#
#          bid_infered  bid_group  bid_final
# 0                  0          0          0
# 1                  0          1          0
# 2                  0          2          0
# 3                  0          3          0
# 4                  0          4          0
# ...              ...        ...        ...
# 2049967            1        374          0
# 2049968            1        374          0
# 2049969            1        374          0
# 2049970            0        374          0
# 2049971            0        375          1
#
# [1869319 rows x 12 columns]

# %%
df4=df3.drop_duplicates(subset=['auction_id','bid_user']).groupby('bid_user').size().sort_values(ascending=False)#reset_index()
df4
# Out:
# bid_user
# Lillyblitz     258
# Npr1967        225
# Drodenbeck     214
# Alad99         191
# Varis          191
#               ...
# Paroca           2
# Dpauken73        2
# Parotgal         2
# Partial          2
# Queenb4u2nv      2
# Length: 37249, dtype: int64

# %%
df5=df3.sort_values('bid_time')
df5=df5.drop_duplicates(subset=['auction_id','bid_user'])
df5
# Out:
#          auction_id             bid_time  bid_ct  bid_number    bid_user  \
# 19003        223829  2009-10-01 22:07:40    2854           1       Sash6
# 19006        223829  2009-10-01 22:51:21     248           4       Rfire
# 19007        223829  2009-10-01 22:52:14     197           5      dome60
# 19014        223829  2009-10-01 22:55:53      14          12  Yllekbryan
# 3924         222653  2009-10-02 03:17:59   36737           1       Rvs66
# ...             ...                  ...     ...         ...         ...
# 2043476      259045  2009-12-12 22:30:36      15          10   Tomr12766
# 2043477      259045  2009-12-12 22:30:36      15          11    Gapkiddo
# 2043478      259045  2009-12-12 22:30:36      15          12     1940neo
# 2043480      259045  2009-12-12 22:30:36      15          14      Dram18
# 2043481      259045  2009-12-12 22:30:37      15          15   Blaze365x
#
#          bid_butler  bid_cp  bid_user_secs_added  bid_butler_secs_added  \
# 19003             0      12                    0                      0
# 19006             0      48                    2                      0
# 19007             0      60                    2                      0
# 19014             0     144                    0                      0
# 3924              0       6                    0                      0
# ...             ...     ...                  ...                    ...
# 2043476           0      60                    0                      0
# 2043477           0      66                    0                      0
# 2043478           0      72                    0                      0
# 2043480           0      84                    0                      0
# 2043481           0      90                    0                      0
#
#          bid_infered  bid_group  bid_final
# 19003              0          0          0
# 19006              0          3          0
# 19007              0          4          0
# 19014              1          9          0
# 3924               0          0          0
# ...              ...        ...        ...
# 2043476            1          6          0
# 2043477            1          6          0
# 2043478            1          6          0
# 2043480            0          6          0
# 2043481            1          7          0
#
# [231115 rows x 12 columns]

# %%
df5['auction_id']=df5['auction_id'].astype(str)

# %%
impressionData=df5.groupby('bid_user')['auction_id'].apply(" ".join).reset_index()
print(impressionData)
# Out:
#               bid_user                                         auction_id
# 0         +34661281XXX                        224875 224929 223626 225739
# 1         +34938723XXX                                      247448 247083
# 2         +34976394XXX                                      239006 240958
# 3        +436604727XXX                                      231525 243429
# 4        +436606822XXX                        229731 248057 249875 250942
# ...                ...                                                ...
# 37244          zarte28  224026 225028 227526 225181 225553 225885 2251...
# 37245           zate28                        250507 250042 248768 248639
# 37246         ziomekpl                                      247712 247018
# 37247  zitronenfalter7                                      252311 255969
# 37248          zorro54                               239349 239339 259044
#
# [37249 rows x 2 columns]

# %%
def noLastOne(text):
  words=text.split()
  if len(words)<=1:
    return ''
  else:
    return ' '.join(words[-51:-1])

def keepLastOne(text):
  newWords=text.split()
  if len(newWords)<1:
    return ''
  else:
     impressionWords=[newWords[-1]]+[str(random.randint(100000, 999999))for _ in range(20)]
     random_index = random.randint(0,len(impressionWords)-1)
     impressionWords[random_index]+='-1'
     return ' '.join(impressionWords)

impressionData['history']=impressionData['auction_id'].apply(noLastOne)
impressionData['impression']=impressionData['auction_id'].apply(keepLastOne)

print(impressionData)
# Out:
#               bid_user                                         auction_id  \
# 0         +34661281XXX                        224875 224929 223626 225739
# 1         +34938723XXX                                      247448 247083
# 2         +34976394XXX                                      239006 240958
# 3        +436604727XXX                                      231525 243429
# 4        +436606822XXX                        229731 248057 249875 250942
# ...                ...                                                ...
# 37244          zarte28  224026 225028 227526 225181 225553 225885 2251...
# 37245           zate28                        250507 250042 248768 248639
# 37246         ziomekpl                                      247712 247018
# 37247  zitronenfalter7                                      252311 255969
# 37248          zorro54                               239349 239339 259044
#
#                                                 history  \
# 0                                  224875 224929 223626
# 1                                                247448
# 2                                                239006
# 3                                                231525
# 4                                  229731 248057 249875
# ...                                                 ...
# 37244  224026 225028 227526 225181 225553 225885 225115
# 37245                              250507 250042 248768
# 37246                                            247712
# 37247                                            252311
# 37248                                     239349 239339
#
#                                               impression
# 0      225739 592016-1 826913 130983 607486 744126 34...
# 1      247083 200696 390674 839443 430937 665852 8252...
# 2      240958 304075 253585 153161 622404 978172 5480...
# 3      243429-1 331568 632942 240601 987558 578014 11...
# 4      250942 902791 707996 837013 449585 632525 3036...
# ...                                                  ...
# 37244  226731 947850 983877 503307 221623 931431 7145...
# 37245  248639 282978 988465 393106 935045 331151 8489...
# 37246  247018 213379 703095 370272 366156 500806 7195...
# 37247  255969 476416 290765 416664 534256 428480 3772...
# 37248  259044 941531 473222 563267 208103 939596 2284...
#
# [37249 rows x 4 columns]

# %%
impression2=impressionData
impression2
# Out:
#               bid_user                                         auction_id  \
# 0         +34661281XXX                        224875 224929 223626 225739
# 1         +34938723XXX                                      247448 247083
# 2         +34976394XXX                                      239006 240958
# 3        +436604727XXX                                      231525 243429
# 4        +436606822XXX                        229731 248057 249875 250942
# ...                ...                                                ...
# 37244          zarte28  224026 225028 227526 225181 225553 225885 2251...
# 37245           zate28                        250507 250042 248768 248639
# 37246         ziomekpl                                      247712 247018
# 37247  zitronenfalter7                                      252311 255969
# 37248          zorro54                               239349 239339 259044
#
#                                                 history  \
# 0                                  224875 224929 223626
# 1                                                247448
# 2                                                239006
# 3                                                231525
# 4                                  229731 248057 249875
# ...                                                 ...
# 37244  224026 225028 227526 225181 225553 225885 225115
# 37245                              250507 250042 248768
# 37246                                            247712
# 37247                                            252311
# 37248                                     239349 239339
#
#                                               impression
# 0      225739 592016-1 826913 130983 607486 744126 34...
# 1      247083 200696 390674 839443 430937 665852 8252...
# 2      240958 304075 253585 153161 622404 978172 5480...
# 3      243429-1 331568 632942 240601 987558 578014 11...
# 4      250942 902791 707996 837013 449585 632525 3036...
# ...                                                  ...
# 37244  226731 947850 983877 503307 221623 931431 7145...
# 37245  248639 282978 988465 393106 935045 331151 8489...
# 37246  247018 213379 703095 370272 366156 500806 7195...
# 37247  255969 476416 290765 416664 534256 428480 3772...
# 37248  259044 941531 473222 563267 208103 939596 2284...
#
# [37249 rows x 4 columns]

# %%
def addZero(text):
    words=text.split()
    newWords=[]
    for word in words:
        if '-1' not in word:
            word+='-0'
        newWords.append(word)

    return ' '.join(newWords)

impression2['impression']=impression2['impression'].apply(addZero)

print(impression2)
# Out:
#               bid_user                                         auction_id  \
# 0         +34661281XXX                        224875 224929 223626 225739
# 1         +34938723XXX                                      247448 247083
# 2         +34976394XXX                                      239006 240958
# 3        +436604727XXX                                      231525 243429
# 4        +436606822XXX                        229731 248057 249875 250942
# ...                ...                                                ...
# 37244          zarte28  224026 225028 227526 225181 225553 225885 2251...
# 37245           zate28                        250507 250042 248768 248639
# 37246         ziomekpl                                      247712 247018
# 37247  zitronenfalter7                                      252311 255969
# 37248          zorro54                               239349 239339 259044
#
#                                                 history  \
# 0                                  224875 224929 223626
# 1                                                247448
# 2                                                239006
# 3                                                231525
# 4                                  229731 248057 249875
# ...                                                 ...
# 37244  224026 225028 227526 225181 225553 225885 225115
# 37245                              250507 250042 248768
# 37246                                            247712
# 37247                                            252311
# 37248                                     239349 239339
#
#                                               impression
# 0      225739-0 592016-1 826913-0 130983-0 607486-0 7...
# 1      247083-0 200696-0 390674-0 839443-0 430937-0 6...
# 2      240958-0 304075-0 253585-0 153161-0 622404-0 9...
# 3      243429-1 331568-0 632942-0 240601-0 987558-0 5...
# 4      250942-0 902791-0 707996-0 837013-0 449585-0 6...
# ...                                                  ...
# 37244  226731-0 947850-0 983877-0 503307-0 221623-0 9...
# 37245  248639-0 282978-0 988465-0 393106-0 935045-0 3...
# 37246  247018-0 213379-0 703095-0 370272-0 366156-0 5...
# 37247  255969-0 476416-0 290765-0 416664-0 534256-0 4...
# 37248  259044-0 941531-0 473222-0 563267-0 208103-0 9...
#
# [37249 rows x 4 columns]

# %%
impression3=impression2.drop('auction_id',axis='columns')
impression3
# Out:
#               bid_user                                           history  \
# 0         +34661281XXX                              224875 224929 223626
# 1         +34938723XXX                                            247448
# 2         +34976394XXX                                            239006
# 3        +436604727XXX                                            231525
# 4        +436606822XXX                              229731 248057 249875
# ...                ...                                               ...
# 37244          zarte28  224026 225028 227526 225181 225553 225885 225115
# 37245           zate28                              250507 250042 248768
# 37246         ziomekpl                                            247712
# 37247  zitronenfalter7                                            252311
# 37248          zorro54                                     239349 239339
#
#                                               impression
# 0      225739-0 592016-1 826913-0 130983-0 607486-0 7...
# 1      247083-0 200696-0 390674-0 839443-0 430937-0 6...
# 2      240958-0 304075-0 253585-0 153161-0 622404-0 9...
# 3      243429-1 331568-0 632942-0 240601-0 987558-0 5...
# 4      250942-0 902791-0 707996-0 837013-0 449585-0 6...
# ...                                                  ...
# 37244  226731-0 947850-0 983877-0 503307-0 221623-0 9...
# 37245  248639-0 282978-0 988465-0 393106-0 935045-0 3...
# 37246  247018-0 213379-0 703095-0 370272-0 366156-0 5...
# 37247  255969-0 476416-0 290765-0 416664-0 534256-0 4...
# 37248  259044-0 941531-0 473222-0 563267-0 208103-0 9...
#
# [37249 rows x 3 columns]

# %%
impression4=impression3.head(10000)
impression4
# Out:
#            bid_user                      history  \
# 0      +34661281XXX         224875 224929 223626
# 1      +34938723XXX                       247448
# 2      +34976394XXX                       239006
# 3     +436604727XXX                       231525
# 4     +436606822XXX         229731 248057 249875
# ...             ...                          ...
# 9995        Ebay920                       233703
# 9996     Ebaynomore  250920 252367 250833 250834
# 9997         Ebby88                       250477
# 9998      Ebeattie6                       245896
# 9999        Ebeau78                       247430
#
#                                              impression
# 0     225739-0 592016-1 826913-0 130983-0 607486-0 7...
# 1     247083-0 200696-0 390674-0 839443-0 430937-0 6...
# 2     240958-0 304075-0 253585-0 153161-0 622404-0 9...
# 3     243429-1 331568-0 632942-0 240601-0 987558-0 5...
# 4     250942-0 902791-0 707996-0 837013-0 449585-0 6...
# ...                                                 ...
# 9995  233577-0 674611-0 586634-0 288974-0 778660-0 3...
# 9996  253759-0 987301-0 606974-0 825643-0 229443-0 3...
# 9997  253305-0 667670-0 547230-0 183060-0 878608-0 8...
# 9998  247636-0 459171-0 335609-0 397834-0 327158-0 6...
# 9999  252829-0 762714-0 298421-0 156325-0 494491-0 1...
#
# [10000 rows x 3 columns]

# %%
impression_time = '11/11/2019 9:05:58 AM'
impression4['impressionTime'] = impression_time
impression4
# Out:
# <ipython-input-30-a78bc265c07a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   impression4['impressionTime'] = impression_time
#            bid_user                      history  \
# 0      +34661281XXX         224875 224929 223626
# 1      +34938723XXX                       247448
# 2      +34976394XXX                       239006
# 3     +436604727XXX                       231525
# 4     +436606822XXX         229731 248057 249875
# ...             ...                          ...
# 9995        Ebay920                       233703
# 9996     Ebaynomore  250920 252367 250833 250834
# 9997         Ebby88                       250477
# 9998      Ebeattie6                       245896
# 9999        Ebeau78                       247430
#
#                                              impression         impressionTime
# 0     225739-0 592016-1 826913-0 130983-0 607486-0 7...  11/11/2019 9:05:58 AM
# 1     247083-0 200696-0 390674-0 839443-0 430937-0 6...  11/11/2019 9:05:58 AM
# 2     240958-0 304075-0 253585-0 153161-0 622404-0 9...  11/11/2019 9:05:58 AM
# 3     243429-1 331568-0 632942-0 240601-0 987558-0 5...  11/11/2019 9:05:58 AM
# 4     250942-0 902791-0 707996-0 837013-0 449585-0 6...  11/11/2019 9:05:58 AM
# ...                                                 ...                    ...
# 9995  233577-0 674611-0 586634-0 288974-0 778660-0 3...  11/11/2019 9:05:58 AM
# 9996  253759-0 987301-0 606974-0 825643-0 229443-0 3...  11/11/2019 9:05:58 AM
# 9997  253305-0 667670-0 547230-0 183060-0 878608-0 8...  11/11/2019 9:05:58 AM
# 9998  247636-0 459171-0 335609-0 397834-0 327158-0 6...  11/11/2019 9:05:58 AM
# 9999  252829-0 762714-0 298421-0 156325-0 494491-0 1...  11/11/2019 9:05:58 AM
#
# [10000 rows x 4 columns]

# %%
impression4=impression4[['bid_user','impressionTime','history','impression']]
impression4
# Out:
#            bid_user         impressionTime                      history  \
# 0      +34661281XXX  11/11/2019 9:05:58 AM         224875 224929 223626
# 1      +34938723XXX  11/11/2019 9:05:58 AM                       247448
# 2      +34976394XXX  11/11/2019 9:05:58 AM                       239006
# 3     +436604727XXX  11/11/2019 9:05:58 AM                       231525
# 4     +436606822XXX  11/11/2019 9:05:58 AM         229731 248057 249875
# ...             ...                    ...                          ...
# 9995        Ebay920  11/11/2019 9:05:58 AM                       233703
# 9996     Ebaynomore  11/11/2019 9:05:58 AM  250920 252367 250833 250834
# 9997         Ebby88  11/11/2019 9:05:58 AM                       250477
# 9998      Ebeattie6  11/11/2019 9:05:58 AM                       245896
# 9999        Ebeau78  11/11/2019 9:05:58 AM                       247430
#
#                                              impression
# 0     225739-0 592016-1 826913-0 130983-0 607486-0 7...
# 1     247083-0 200696-0 390674-0 839443-0 430937-0 6...
# 2     240958-0 304075-0 253585-0 153161-0 622404-0 9...
# 3     243429-1 331568-0 632942-0 240601-0 987558-0 5...
# 4     250942-0 902791-0 707996-0 837013-0 449585-0 6...
# ...                                                 ...
# 9995  233577-0 674611-0 586634-0 288974-0 778660-0 3...
# 9996  253759-0 987301-0 606974-0 825643-0 229443-0 3...
# 9997  253305-0 667670-0 547230-0 183060-0 878608-0 8...
# 9998  247636-0 459171-0 335609-0 397834-0 327158-0 6...
# 9999  252829-0 762714-0 298421-0 156325-0 494491-0 1...
#
# [10000 rows x 4 columns]

# %%
impression4.to_csv('behavior10000.tsv',header=False,sep="\t")
