# %%
import pandas as pd
import numpy as np
import random
from sklearn.model_selection import train_test_split

# %%
df1=pd.read_table('traces.tsv')
df1
# Out:
#          auction_id             bid_time  bid_ct  bid_number      bid_user  \
# 0            222387  2009-10-04 12:33:26   19913           1    Becker1990
# 1            222387  2009-10-04 14:28:14   13029           2      Gaynor66
# 2            222387  2009-10-04 14:44:08   12079           3     Jostrem16
# 3            222387  2009-10-04 17:14:26    3071           4     Clubfan78
# 4            222387  2009-10-04 17:36:06    1773           5    Momstired2
# ...             ...                  ...     ...         ...           ...
# 2049967      259070  2009-12-12 21:29:30      15         517    Blaufish83
# 2049968      259070  2009-12-12 21:29:30      15         518      Solwicca
# 2049969      259070  2009-12-12 21:29:30      15         519      Jaden248
# 2049970      259070  2009-12-12 21:29:30      15         520       Orion29
# 2049971      259070  2009-12-12 21:29:34      15         521  Schonmir1500
#
#          bid_butler  bid_cp  bid_user_secs_added  bid_butler_secs_added  \
# 0                 0      12                    0                      0
# 1                 0      24                    4                      0
# 2                 0      36                    4                      0
# 3                 0      48                   10                      0
# 4                 0      60                    2                      0
# ...             ...     ...                  ...                    ...
# 2049967           0    3102                   14                      0
# 2049968           0    3108                   14                      0
# 2049969           0    3114                   14                      0
# 2049970           0    3120                   14                      0
# 2049971           0    3126                    4                      0
#
#          bid_infered  bid_group  bid_final
# 0                  0          0          0
# 1                  0          1          0
# 2                  0          2          0
# 3                  0          3          0
# 4                  0          4          0
# ...              ...        ...        ...
# 2049967            1        374          0
# 2049968            1        374          0
# 2049969            1        374          0
# 2049970            0        374          0
# 2049971            0        375          1
#
# [2049972 rows x 12 columns]

# %%
df2=df1.drop_duplicates(subset=['auction_id','bid_user']).groupby('bid_user').size().sort_values(ascending=False).reset_index()
df2.columns =['bid_user', 'counts']
df2
# Out:
#          bid_user  counts
# 0      Lillyblitz     258
# 1         Npr1967     225
# 2      Drodenbeck     214
# 3       Zwerg1953     191
# 4           Varis     191
# ...           ...     ...
# 60532   Keebler87       1
# 60533       Kedii       1
# 60534     Kebo178       1
# 60535    Keber314       1
# 60536      zzindy       1
#
# [60537 rows x 2 columns]

# %%
df2=df2[df2['counts']>=2]
df2
# Out:
#          bid_user  counts
# 0      Lillyblitz     258
# 1         Npr1967     225
# 2      Drodenbeck     214
# 3       Zwerg1953     191
# 4           Varis     191
# ...           ...     ...
# 37244      Dansgr       2
# 37245     Julsche       2
# 37246  Topdolly75       2
# 37247   Topazlady       2
# 37248      Sinopa       2
#
# [37249 rows x 2 columns]

# %%
df3=df1[df1['bid_user'].isin(df2['bid_user'].tolist())]
df3
# Out:
#          auction_id             bid_time  bid_ct  bid_number      bid_user  \
# 0            222387  2009-10-04 12:33:26   19913           1    Becker1990
# 1            222387  2009-10-04 14:28:14   13029           2      Gaynor66
# 2            222387  2009-10-04 14:44:08   12079           3     Jostrem16
# 3            222387  2009-10-04 17:14:26    3071           4     Clubfan78
# 4            222387  2009-10-04 17:36:06    1773           5    Momstired2
# ...             ...                  ...     ...         ...           ...
# 2049967      259070  2009-12-12 21:29:30      15         517    Blaufish83
# 2049968      259070  2009-12-12 21:29:30      15         518      Solwicca
# 2049969      259070  2009-12-12 21:29:30      15         519      Jaden248
# 2049970      259070  2009-12-12 21:29:30      15         520       Orion29
# 2049971      259070  2009-12-12 21:29:34      15         521  Schonmir1500
#
#          bid_butler  bid_cp  bid_user_secs_added  bid_butler_secs_added  \
# 0                 0      12                    0                      0
# 1                 0      24                    4                      0
# 2                 0      36                    4                      0
# 3                 0      48                   10                      0
# 4                 0      60                    2                      0
# ...             ...     ...                  ...                    ...
# 2049967           0    3102                   14                      0
# 2049968           0    3108                   14                      0
# 2049969           0    3114                   14                      0
# 2049970           0    3120                   14                      0
# 2049971           0    3126                    4                      0
#
#          bid_infered  bid_group  bid_final
# 0                  0          0          0
# 1                  0          1          0
# 2                  0          2          0
# 3                  0          3          0
# 4                  0          4          0
# ...              ...        ...        ...
# 2049967            1        374          0
# 2049968            1        374          0
# 2049969            1        374          0
# 2049970            0        374          0
# 2049971            0        375          1
#
# [1869319 rows x 12 columns]

# %%
df4=df3.drop_duplicates(subset=['auction_id','bid_user']).groupby('bid_user').size().sort_values(ascending=False)#reset_index()
df4
# Out:
# bid_user
# Lillyblitz     258
# Npr1967        225
# Drodenbeck     214
# Alad99         191
# Varis          191
#               ...
# Paroca           2
# Dpauken73        2
# Parotgal         2
# Partial          2
# Queenb4u2nv      2
# Length: 37249, dtype: int64

# %%
df5=df3.sort_values('bid_time')
df5=df5.drop_duplicates(subset=['auction_id','bid_user'])
df5
# Out:
#          auction_id             bid_time  bid_ct  bid_number    bid_user  \
# 19003        223829  2009-10-01 22:07:40    2854           1       Sash6
# 19006        223829  2009-10-01 22:51:21     248           4       Rfire
# 19007        223829  2009-10-01 22:52:14     197           5      dome60
# 19014        223829  2009-10-01 22:55:53      14          12  Yllekbryan
# 3924         222653  2009-10-02 03:17:59   36737           1       Rvs66
# ...             ...                  ...     ...         ...         ...
# 2043476      259045  2009-12-12 22:30:36      15          10   Tomr12766
# 2043477      259045  2009-12-12 22:30:36      15          11    Gapkiddo
# 2043478      259045  2009-12-12 22:30:36      15          12     1940neo
# 2043480      259045  2009-12-12 22:30:36      15          14      Dram18
# 2043481      259045  2009-12-12 22:30:37      15          15   Blaze365x
#
#          bid_butler  bid_cp  bid_user_secs_added  bid_butler_secs_added  \
# 19003             0      12                    0                      0
# 19006             0      48                    2                      0
# 19007             0      60                    2                      0
# 19014             0     144                    0                      0
# 3924              0       6                    0                      0
# ...             ...     ...                  ...                    ...
# 2043476           0      60                    0                      0
# 2043477           0      66                    0                      0
# 2043478           0      72                    0                      0
# 2043480           0      84                    0                      0
# 2043481           0      90                    0                      0
#
#          bid_infered  bid_group  bid_final
# 19003              0          0          0
# 19006              0          3          0
# 19007              0          4          0
# 19014              1          9          0
# 3924               0          0          0
# ...              ...        ...        ...
# 2043476            1          6          0
# 2043477            1          6          0
# 2043478            1          6          0
# 2043480            0          6          0
# 2043481            1          7          0
#
# [231115 rows x 12 columns]

# %%
df5['auction_id']=df5['auction_id'].astype(str)

# %%
impressionData=df5.groupby('bid_user')['auction_id'].apply(" ".join).reset_index()
print(impressionData)
# Out:
#               bid_user                                         auction_id
# 0         +34661281XXX                        224875 224929 223626 225739
# 1         +34938723XXX                                      247448 247083
# 2         +34976394XXX                                      239006 240958
# 3        +436604727XXX                                      231525 243429
# 4        +436606822XXX                        229731 248057 249875 250942
# ...                ...                                                ...
# 37244          zarte28  224026 225028 227526 225181 225553 225885 2251...
# 37245           zate28                        250507 250042 248768 248639
# 37246         ziomekpl                                      247712 247018
# 37247  zitronenfalter7                                      252311 255969
# 37248          zorro54                               239349 239339 259044
#
# [37249 rows x 2 columns]

# %%
def noLastOne(text):
  words=text.split()
  if len(words)<=1:
    return ''
  else:
    return ' '.join(words[-51:-1])

def keepLastOne(text):
  newWords=text.split()
  if len(newWords)<1:
    return ''
  else:
     impressionWords=[newWords[-1]]+[str(random.randint(100000, 999999))for _ in range(20)]
     random_index = random.randint(0,len(impressionWords)-1)
     impressionWords[random_index]+='-1'
     return ' '.join(impressionWords)

impressionData['history']=impressionData['auction_id'].apply(noLastOne)
impressionData['impression']=impressionData['auction_id'].apply(keepLastOne)

print(impressionData)
# Out:
#               bid_user                                         auction_id  \
# 0         +34661281XXX                        224875 224929 223626 225739
# 1         +34938723XXX                                      247448 247083
# 2         +34976394XXX                                      239006 240958
# 3        +436604727XXX                                      231525 243429
# 4        +436606822XXX                        229731 248057 249875 250942
# ...                ...                                                ...
# 37244          zarte28  224026 225028 227526 225181 225553 225885 2251...
# 37245           zate28                        250507 250042 248768 248639
# 37246         ziomekpl                                      247712 247018
# 37247  zitronenfalter7                                      252311 255969
# 37248          zorro54                               239349 239339 259044
#
#                                                 history  \
# 0                                  224875 224929 223626
# 1                                                247448
# 2                                                239006
# 3                                                231525
# 4                                  229731 248057 249875
# ...                                                 ...
# 37244  224026 225028 227526 225181 225553 225885 225115
# 37245                              250507 250042 248768
# 37246                                            247712
# 37247                                            252311
# 37248                                     239349 239339
#
#                                               impression
# 0      225739-1 616385 904296 913665 254636 999036 13...
# 1      247083 933435 759895 164581 498021 273652 4833...
# 2      240958 710551 417052 325127 843486 907929 6441...
# 3      243429 769424 442372 448775 869638 704826 7023...
# 4      250942 652692 488302 332812-1 558752 903752 90...
# ...                                                  ...
# 37244  226731 805776 425337 909427 332174 763144 5898...
# 37245  248639 510388 418760 430976 287731 954251 3705...
# 37246  247018 937804 171423 546454-1 383567 385726 76...
# 37247  255969 820938 412301 916234 590075 305111 5706...
# 37248  259044 219242 601901 499058 236605 329719 6172...
#
# [37249 rows x 4 columns]

# %%
impression2=impressionData
impression2
# Out:
#               bid_user                                         auction_id  \
# 0         +34661281XXX                        224875 224929 223626 225739
# 1         +34938723XXX                                      247448 247083
# 2         +34976394XXX                                      239006 240958
# 3        +436604727XXX                                      231525 243429
# 4        +436606822XXX                        229731 248057 249875 250942
# ...                ...                                                ...
# 37244          zarte28  224026 225028 227526 225181 225553 225885 2251...
# 37245           zate28                        250507 250042 248768 248639
# 37246         ziomekpl                                      247712 247018
# 37247  zitronenfalter7                                      252311 255969
# 37248          zorro54                               239349 239339 259044
#
#                                                 history  \
# 0                                  224875 224929 223626
# 1                                                247448
# 2                                                239006
# 3                                                231525
# 4                                  229731 248057 249875
# ...                                                 ...
# 37244  224026 225028 227526 225181 225553 225885 225115
# 37245                              250507 250042 248768
# 37246                                            247712
# 37247                                            252311
# 37248                                     239349 239339
#
#                                               impression
# 0      225739-1 616385 904296 913665 254636 999036 13...
# 1      247083 933435 759895 164581 498021 273652 4833...
# 2      240958 710551 417052 325127 843486 907929 6441...
# 3      243429 769424 442372 448775 869638 704826 7023...
# 4      250942 652692 488302 332812-1 558752 903752 90...
# ...                                                  ...
# 37244  226731 805776 425337 909427 332174 763144 5898...
# 37245  248639 510388 418760 430976 287731 954251 3705...
# 37246  247018 937804 171423 546454-1 383567 385726 76...
# 37247  255969 820938 412301 916234 590075 305111 5706...
# 37248  259044 219242 601901 499058 236605 329719 6172...
#
# [37249 rows x 4 columns]

# %%
def addZero(text):
    words=text.split()
    newWords=[]
    for word in words:
        if '-1' not in word:
            word+='-0'
        newWords.append(word)

    return ' '.join(newWords)

impression2['impression']=impression2['impression'].apply(addZero)

print(impression2)
# Out:
#               bid_user                                         auction_id  \
# 0         +34661281XXX                        224875 224929 223626 225739
# 1         +34938723XXX                                      247448 247083
# 2         +34976394XXX                                      239006 240958
# 3        +436604727XXX                                      231525 243429
# 4        +436606822XXX                        229731 248057 249875 250942
# ...                ...                                                ...
# 37244          zarte28  224026 225028 227526 225181 225553 225885 2251...
# 37245           zate28                        250507 250042 248768 248639
# 37246         ziomekpl                                      247712 247018
# 37247  zitronenfalter7                                      252311 255969
# 37248          zorro54                               239349 239339 259044
#
#                                                 history  \
# 0                                  224875 224929 223626
# 1                                                247448
# 2                                                239006
# 3                                                231525
# 4                                  229731 248057 249875
# ...                                                 ...
# 37244  224026 225028 227526 225181 225553 225885 225115
# 37245                              250507 250042 248768
# 37246                                            247712
# 37247                                            252311
# 37248                                     239349 239339
#
#                                               impression
# 0      225739-1 616385-0 904296-0 913665-0 254636-0 9...
# 1      247083-0 933435-0 759895-0 164581-0 498021-0 2...
# 2      240958-0 710551-0 417052-0 325127-0 843486-0 9...
# 3      243429-0 769424-0 442372-0 448775-0 869638-0 7...
# 4      250942-0 652692-0 488302-0 332812-1 558752-0 9...
# ...                                                  ...
# 37244  226731-0 805776-0 425337-0 909427-0 332174-0 7...
# 37245  248639-0 510388-0 418760-0 430976-0 287731-0 9...
# 37246  247018-0 937804-0 171423-0 546454-1 383567-0 3...
# 37247  255969-0 820938-0 412301-0 916234-0 590075-0 3...
# 37248  259044-0 219242-0 601901-0 499058-0 236605-0 3...
#
# [37249 rows x 4 columns]

# %%
impression3=impression2.drop('auction_id',axis='columns')
impression3
# Out:
#               bid_user                                           history  \
# 0         +34661281XXX                              224875 224929 223626
# 1         +34938723XXX                                            247448
# 2         +34976394XXX                                            239006
# 3        +436604727XXX                                            231525
# 4        +436606822XXX                              229731 248057 249875
# ...                ...                                               ...
# 37244          zarte28  224026 225028 227526 225181 225553 225885 225115
# 37245           zate28                              250507 250042 248768
# 37246         ziomekpl                                            247712
# 37247  zitronenfalter7                                            252311
# 37248          zorro54                                     239349 239339
#
#                                               impression
# 0      225739-1 616385-0 904296-0 913665-0 254636-0 9...
# 1      247083-0 933435-0 759895-0 164581-0 498021-0 2...
# 2      240958-0 710551-0 417052-0 325127-0 843486-0 9...
# 3      243429-0 769424-0 442372-0 448775-0 869638-0 7...
# 4      250942-0 652692-0 488302-0 332812-1 558752-0 9...
# ...                                                  ...
# 37244  226731-0 805776-0 425337-0 909427-0 332174-0 7...
# 37245  248639-0 510388-0 418760-0 430976-0 287731-0 9...
# 37246  247018-0 937804-0 171423-0 546454-1 383567-0 3...
# 37247  255969-0 820938-0 412301-0 916234-0 590075-0 3...
# 37248  259044-0 219242-0 601901-0 499058-0 236605-0 3...
#
# [37249 rows x 3 columns]

# %%
#impression4=impression3.head(10000)
#impression4
# Out:
#            bid_user                      history  \
# 0      +34661281XXX         224875 224929 223626
# 1      +34938723XXX                       247448
# 2      +34976394XXX                       239006
# 3     +436604727XXX                       231525
# 4     +436606822XXX         229731 248057 249875
# ...             ...                          ...
# 9995        Ebay920                       233703
# 9996     Ebaynomore  250920 252367 250833 250834
# 9997         Ebby88                       250477
# 9998      Ebeattie6                       245896
# 9999        Ebeau78                       247430
#
#                                              impression
# 0     225739-0 592016-1 826913-0 130983-0 607486-0 7...
# 1     247083-0 200696-0 390674-0 839443-0 430937-0 6...
# 2     240958-0 304075-0 253585-0 153161-0 622404-0 9...
# 3     243429-1 331568-0 632942-0 240601-0 987558-0 5...
# 4     250942-0 902791-0 707996-0 837013-0 449585-0 6...
# ...                                                 ...
# 9995  233577-0 674611-0 586634-0 288974-0 778660-0 3...
# 9996  253759-0 987301-0 606974-0 825643-0 229443-0 3...
# 9997  253305-0 667670-0 547230-0 183060-0 878608-0 8...
# 9998  247636-0 459171-0 335609-0 397834-0 327158-0 6...
# 9999  252829-0 762714-0 298421-0 156325-0 494491-0 1...
#
# [10000 rows x 3 columns]

# %%
impression_time = '11/11/2019 9:05:58 AM'
impression3['impressionTime'] = impression_time
impression3
# Out:
#               bid_user                                           history  \
# 0         +34661281XXX                              224875 224929 223626
# 1         +34938723XXX                                            247448
# 2         +34976394XXX                                            239006
# 3        +436604727XXX                                            231525
# 4        +436606822XXX                              229731 248057 249875
# ...                ...                                               ...
# 37244          zarte28  224026 225028 227526 225181 225553 225885 225115
# 37245           zate28                              250507 250042 248768
# 37246         ziomekpl                                            247712
# 37247  zitronenfalter7                                            252311
# 37248          zorro54                                     239349 239339
#
#                                               impression  \
# 0      225739-1 616385-0 904296-0 913665-0 254636-0 9...
# 1      247083-0 933435-0 759895-0 164581-0 498021-0 2...
# 2      240958-0 710551-0 417052-0 325127-0 843486-0 9...
# 3      243429-0 769424-0 442372-0 448775-0 869638-0 7...
# 4      250942-0 652692-0 488302-0 332812-1 558752-0 9...
# ...                                                  ...
# 37244  226731-0 805776-0 425337-0 909427-0 332174-0 7...
# 37245  248639-0 510388-0 418760-0 430976-0 287731-0 9...
# 37246  247018-0 937804-0 171423-0 546454-1 383567-0 3...
# 37247  255969-0 820938-0 412301-0 916234-0 590075-0 3...
# 37248  259044-0 219242-0 601901-0 499058-0 236605-0 3...
#
#               impressionTime
# 0      11/11/2019 9:05:58 AM
# 1      11/11/2019 9:05:58 AM
# 2      11/11/2019 9:05:58 AM
# 3      11/11/2019 9:05:58 AM
# 4      11/11/2019 9:05:58 AM
# ...                      ...
# 37244  11/11/2019 9:05:58 AM
# 37245  11/11/2019 9:05:58 AM
# 37246  11/11/2019 9:05:58 AM
# 37247  11/11/2019 9:05:58 AM
# 37248  11/11/2019 9:05:58 AM
#
# [37249 rows x 4 columns]

# %%
impression3=impression3[['bid_user','impressionTime','history','impression']]
impression3
# Out:
#               bid_user         impressionTime  \
# 0         +34661281XXX  11/11/2019 9:05:58 AM
# 1         +34938723XXX  11/11/2019 9:05:58 AM
# 2         +34976394XXX  11/11/2019 9:05:58 AM
# 3        +436604727XXX  11/11/2019 9:05:58 AM
# 4        +436606822XXX  11/11/2019 9:05:58 AM
# ...                ...                    ...
# 37244          zarte28  11/11/2019 9:05:58 AM
# 37245           zate28  11/11/2019 9:05:58 AM
# 37246         ziomekpl  11/11/2019 9:05:58 AM
# 37247  zitronenfalter7  11/11/2019 9:05:58 AM
# 37248          zorro54  11/11/2019 9:05:58 AM
#
#                                                 history  \
# 0                                  224875 224929 223626
# 1                                                247448
# 2                                                239006
# 3                                                231525
# 4                                  229731 248057 249875
# ...                                                 ...
# 37244  224026 225028 227526 225181 225553 225885 225115
# 37245                              250507 250042 248768
# 37246                                            247712
# 37247                                            252311
# 37248                                     239349 239339
#
#                                               impression
# 0      225739-1 616385-0 904296-0 913665-0 254636-0 9...
# 1      247083-0 933435-0 759895-0 164581-0 498021-0 2...
# 2      240958-0 710551-0 417052-0 325127-0 843486-0 9...
# 3      243429-0 769424-0 442372-0 448775-0 869638-0 7...
# 4      250942-0 652692-0 488302-0 332812-1 558752-0 9...
# ...                                                  ...
# 37244  226731-0 805776-0 425337-0 909427-0 332174-0 7...
# 37245  248639-0 510388-0 418760-0 430976-0 287731-0 9...
# 37246  247018-0 937804-0 171423-0 546454-1 383567-0 3...
# 37247  255969-0 820938-0 412301-0 916234-0 590075-0 3...
# 37248  259044-0 219242-0 601901-0 499058-0 236605-0 3...
#
# [37249 rows x 4 columns]

# %%
train_data, val_data = train_test_split(impression3, test_size=0.3, random_state=100)

# %%
train_data
# Out:
#              bid_user         impressionTime  \
# 33213       Theking74  11/11/2019 9:05:58 AM
# 18089         Kino555  11/11/2019 9:05:58 AM
# 19716          Lmitch  11/11/2019 9:05:58 AM
# 9456        Dooby2008  11/11/2019 9:05:58 AM
# 8921      Digitalfail  11/11/2019 9:05:58 AM
# ...               ...                    ...
# 16734          Joyces  11/11/2019 9:05:58 AM
# 16304    Joaniecheney  11/11/2019 9:05:58 AM
# 79     +4917641092XXX  11/11/2019 9:05:58 AM
# 12119         Gcougar  11/11/2019 9:05:58 AM
# 14147       Hollyface  11/11/2019 9:05:58 AM
#
#                                                  history  \
# 33213  225354 226994 226149 240824 240589 239466 2389...
# 18089  244553 243420 242878 243443 243444 243453 2434...
# 19716                               248783 251823 248780
# 9456                         248638 248636 251879 250292
# 8921                                       249881 249802
# ...                                                  ...
# 16734                               225844 229933 243139
# 16304                               232607 232614 232606
# 79                                                250144
# 12119                                             231048
# 14147                                             246987
#
#                                               impression
# 33213  244829-0 779670-0 880354-1 739054-0 180993-0 6...
# 18089  257041-1 283585-0 313694-0 496357-0 187411-0 2...
# 19716  256471-0 690817-0 756461-0 307002-0 999342-0 8...
# 9456   252600-0 419830-0 689837-0 267631-0 328955-0 8...
# 8921   249890-0 976267-0 343406-1 163124-0 158218-0 7...
# ...                                                  ...
# 16734  255836-0 427532-0 527503-0 325639-0 658778-0 3...
# 16304  234029-0 390384-0 935070-0 535074-0 758450-0 6...
# 79     253403-0 597152-0 207281-0 533323-0 745572-0 5...
# 12119  233541-0 606151-0 924520-0 830125-0 534358-0 7...
# 14147  251879-0 426589-0 593502-0 949383-0 116076-0 7...
#
# [26074 rows x 4 columns]

# %%
val_data
# Out:
#           bid_user         impressionTime  \
# 21221       Masoin  11/11/2019 9:05:58 AM
# 9358   Dominik1981  11/11/2019 9:05:58 AM
# 35120        Vishi  11/11/2019 9:05:58 AM
# 6492    Chipsticks  11/11/2019 9:05:58 AM
# 6824   Clarkie1007  11/11/2019 9:05:58 AM
# ...            ...                    ...
# 20853      Marcaro  11/11/2019 9:05:58 AM
# 23042       Mpjubb  11/11/2019 9:05:58 AM
# 28761      Ryzom88  11/11/2019 9:05:58 AM
# 22889    Moonbeam1  11/11/2019 9:05:58 AM
# 33293  Thetradersl  11/11/2019 9:05:58 AM
#
#                                                  history  \
# 21221                                             249841
# 9358           248449 251844 251888 248432 250523 248513
# 35120                                             244724
# 6492                                222657 222658 224219
# 6824                                              232633
# ...                                                  ...
# 20853                                             240468
# 23042                               229218 229204 229197
# 28761                        227805 227882 227807 229488
# 22889  234070 231463 231469 233984 231470 235986 2392...
# 33293                                             232588
#
#                                               impression
# 21221  249737-0 431265-0 470952-1 626545-0 944362-0 9...
# 9358   251863-0 766803-0 132165-1 329743-0 479634-0 4...
# 35120  243328-0 642635-0 331373-0 792992-0 657184-0 3...
# 6492   222659-0 904155-0 756390-0 573695-0 329684-0 6...
# 6824   231055-0 540312-0 736230-1 274859-0 407745-0 1...
# ...                                                  ...
# 20853  240471-0 129182-0 936177-0 132150-0 997494-0 7...
# 23042  229217-0 128910-1 443447-0 409294-0 977573-0 8...
# 28761  227731-1 381313-0 100547-0 390799-0 459169-0 8...
# 22889  250857-0 236794-0 515820-1 925129-0 377984-0 4...
# 33293  232589-0 596187-0 738258-1 294785-0 830566-0 3...
#
# [11175 rows x 4 columns]

# %%
train_data.to_csv('behaviorTrain_data.tsv',header=False,sep="\t")

# %%
val_data.to_csv('behaviorVal_data.tsv',header=False,sep="\t")
