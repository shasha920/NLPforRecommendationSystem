# %%
import pandas as pd
import numpy as np
import re

# %%
columns_name =['bid_user','impressionTime','history','impression']
df=pd.read_csv('behaviorVal_data.tsv',sep="\t",names=columns_name)
df
# Out:
#           bid_user         impressionTime  \
# 21221       Masoin  11/11/2019 9:05:58 AM
# 9358   Dominik1981  11/11/2019 9:05:58 AM
# 35120        Vishi  11/11/2019 9:05:58 AM
# 6492    Chipsticks  11/11/2019 9:05:58 AM
# 6824   Clarkie1007  11/11/2019 9:05:58 AM
# ...            ...                    ...
# 20853      Marcaro  11/11/2019 9:05:58 AM
# 23042       Mpjubb  11/11/2019 9:05:58 AM
# 28761      Ryzom88  11/11/2019 9:05:58 AM
# 22889    Moonbeam1  11/11/2019 9:05:58 AM
# 33293  Thetradersl  11/11/2019 9:05:58 AM
#
#                                                  history  \
# 21221                                             249841
# 9358           248449 251844 251888 248432 250523 248513
# 35120                                             244724
# 6492                                222657 222658 224219
# 6824                                              232633
# ...                                                  ...
# 20853                                             240468
# 23042                               229218 229204 229197
# 28761                        227805 227882 227807 229488
# 22889  234070 231463 231469 233984 231470 235986 2392...
# 33293                                             232588
#
#                                               impression
# 21221  249737-0 431265-0 470952-1 626545-0 944362-0 9...
# 9358   251863-0 766803-0 132165-1 329743-0 479634-0 4...
# 35120  243328-0 642635-0 331373-0 792992-0 657184-0 3...
# 6492   222659-0 904155-0 756390-0 573695-0 329684-0 6...
# 6824   231055-0 540312-0 736230-1 274859-0 407745-0 1...
# ...                                                  ...
# 20853  240471-0 129182-0 936177-0 132150-0 997494-0 7...
# 23042  229217-0 128910-1 443447-0 409294-0 977573-0 8...
# 28761  227731-1 381313-0 100547-0 390799-0 459169-0 8...
# 22889  250857-0 236794-0 515820-1 925129-0 377984-0 4...
# 33293  232589-0 596187-0 738258-1 294785-0 830566-0 3...
#
# [11175 rows x 4 columns]

# %%
df2=df.impression
df2
# Out:
# 21221    249737-0 431265-0 470952-1 626545-0 944362-0 9...
# 9358     251863-0 766803-0 132165-1 329743-0 479634-0 4...
# 35120    243328-0 642635-0 331373-0 792992-0 657184-0 3...
# 6492     222659-0 904155-0 756390-0 573695-0 329684-0 6...
# 6824     231055-0 540312-0 736230-1 274859-0 407745-0 1...
#                                ...
# 20853    240471-0 129182-0 936177-0 132150-0 997494-0 7...
# 23042    229217-0 128910-1 443447-0 409294-0 977573-0 8...
# 28761    227731-1 381313-0 100547-0 390799-0 459169-0 8...
# 22889    250857-0 236794-0 515820-1 925129-0 377984-0 4...
# 33293    232589-0 596187-0 738258-1 294785-0 830566-0 3...
# Name: impression, Length: 11175, dtype: object

# %%
def split_and_flatten(row):
    impressions = row['impression'].split()
    flattened = [item.split('-')[0] for item in impressions]
    return ' '.join(flattened)


df['new_dataset'] = df.apply(split_and_flatten, axis=1)


print(df[['new_dataset']])
# Out:
#                                              new_dataset
# 21221  249737 431265 470952 626545 944362 949328 9774...
# 9358   251863 766803 132165 329743 479634 424370 3259...
# 35120  243328 642635 331373 792992 657184 339858 1451...
# 6492   222659 904155 756390 573695 329684 639103 9387...
# 6824   231055 540312 736230 274859 407745 192474 3076...
# ...                                                  ...
# 20853  240471 129182 936177 132150 997494 754017 4147...
# 23042  229217 128910 443447 409294 977573 846787 8606...
# 28761  227731 381313 100547 390799 459169 815159 2800...
# 22889  250857 236794 515820 925129 377984 450742 8557...
# 33293  232589 596187 738258 294785 830566 308407 7875...
#
# [11175 rows x 1 columns]

# %%
new_df = df['new_dataset'].str.split().explode().reset_index(drop=True)

new_df = new_df.rename('split_values')


df6 = pd.DataFrame({'auction_id': new_df})


print(df6)
# Out:
#        auction_id
# 0          249737
# 1          431265
# 2          470952
# 3          626545
# 4          944362
# ...           ...
# 234670     276206
# 234671     848784
# 234672     550985
# 234673     798333
# 234674     566329
#
# [234675 rows x 1 columns]

# %%
df7=df.history
df7
# Out:
# 21221                                               249841
# 9358             248449 251844 251888 248432 250523 248513
# 35120                                               244724
# 6492                                  222657 222658 224219
# 6824                                                232633
#                                ...
# 20853                                               240468
# 23042                                 229218 229204 229197
# 28761                          227805 227882 227807 229488
# 22889    234070 231463 231469 233984 231470 235986 2392...
# 33293                                               232588
# Name: history, Length: 11175, dtype: object

# %%
df7.columns =['new_datasets']
df7
# Out:
# 21221                                               249841
# 9358             248449 251844 251888 248432 250523 248513
# 35120                                               244724
# 6492                                  222657 222658 224219
# 6824                                                232633
#                                ...
# 20853                                               240468
# 23042                                 229218 229204 229197
# 28761                          227805 227882 227807 229488
# 22889    234070 231463 231469 233984 231470 235986 2392...
# 33293                                               232588
# Name: history, Length: 11175, dtype: object

# %%
new_df = df7.str.split().explode()

new_df = new_df.rename('split_values')


df7 = pd.DataFrame({'auction_id': new_df})

print(df7)
# Out:
#       auction_id
# 21221     249841
# 9358      248449
# 9358      251844
# 9358      251888
# 9358      248432
# ...          ...
# 22889     239387
# 22889     240826
# 22889     244697
# 22889     249745
# 33293     232588
#
# [54438 rows x 1 columns]

# %%
df7.reset_index(drop=True, inplace=True)
df7
# Out:
#       auction_id
# 0         249841
# 1         248449
# 2         251844
# 3         251888
# 4         248432
# ...          ...
# 54433     239387
# 54434     240826
# 54435     244697
# 54436     249745
# 54437     232588
#
# [54438 rows x 1 columns]

# %%
df7.dtypes
# Out:
# auction_id    object
# dtype: object

# %%
df1=pd.read_table('outcomes.tsv')
df1.head()
# Out:
#    auction_id  product_id                                      item  \
# 0       86827    10009602  sony-ericsson-s500i-unlocked-mysterious-
# 1       87964    10009881            psp-slim-lite-sony-piano-black
# 2       87965    10009881            psp-slim-lite-sony-piano-black
# 3       88638    10006115  sony-ericsson-s500i-unlocked-mysterious-
# 4       88639    10006115  sony-ericsson-s500i-unlocked-mysterious-
#
#                                             desc  retail  price  finalprice  \
# 0  Sony Ericsson S500i Unlocked Mysterious Green  499.99  13.35       13.35
# 1               PSP Slim & Lite Sony Piano Black  169.99  74.70       74.70
# 2               PSP Slim & Lite Sony Piano Black  169.99  83.10       83.10
# 3  Sony Ericsson S500i Unlocked Mysterious Green  499.99  19.65       19.65
# 4  Sony Ericsson S500i Unlocked Mysterious Green  499.99  47.10       47.10
#
#    bidincrement  bidfee        winner  placedbids  freebids  \
# 0            15      75       Racer11          26         0
# 1            15      75        Cemo23          65         0
# 2            15      75  Jacobsonnich          94         0
# 3            15      75        Mokkis          10         0
# 4            15      75  Superloeffel          80         0
#
#             endtime_str  flg_click_only  flg_beginnerauction  flg_fixedprice  \
# 0  19:52 PDT 09-16-2008               0                    0               0
# 1  11:17 PDT 08-28-2008               0                    0               0
# 2  22:52 PDT 11-07-2008               0                    1               0
# 3  22:02 PDT 08-23-2008               0                    0               0
# 4  14:23 PDT 08-24-2008               0                    0               0
#
#    flg_endprice
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
df8=df1.drop(['product_id','item','retail','price','finalprice','bidincrement','bidfee','winner','placedbids','freebids','endtime_str','flg_click_only','flg_beginnerauction','flg_fixedprice','flg_endprice'],axis='columns')
df8
# Out:
#         auction_id                                           desc
# 0            86827  Sony Ericsson S500i Unlocked Mysterious Green
# 1            87964               PSP Slim & Lite Sony Piano Black
# 2            87965               PSP Slim & Lite Sony Piano Black
# 3            88638  Sony Ericsson S500i Unlocked Mysterious Green
# 4            88639  Sony Ericsson S500i Unlocked Mysterious Green
# ...            ...                                            ...
# 121414      259065                               300 Bids Voucher
# 121415      259066                               300 Bids Voucher
# 121416      259068                               300 Bids Voucher
# 121417      259069                               300 Bids Voucher
# 121418      259070                               300 Bids Voucher
#
# [121419 rows x 2 columns]

# %%
df8.auction_id.dtypes
# Out:
# dtype('int64')

# %%
#df11=df8.loc[df8.auction_id.isin(df7.auction_id)]
#df11
# Out:
#         auction_id                                          desc
# 99110       222389       Guitar Hero World Tour Guitar Kit (Wii)
# 99115       222394  Guitar Hero World Tour Guitar Kit (Xbox 360)
# 99116       222395  Guitar Hero World Tour Guitar Kit (Xbox 360)
# 99165       222444                          The Reader [Blu-ray]
# 99185       222464      Professor Layton and the Curious Village
# ...            ...                                           ...
# 121407      259058                              300 Bids Voucher
# 121408      259059                              300 Bids Voucher
# 121412      259063                              300 Bids Voucher
# 121414      259065                              300 Bids Voucher
# 121415      259066                              300 Bids Voucher
#
# [3050 rows x 2 columns]

# %%
df8['auction_id'] = df8['auction_id'].astype(str)
df7['auction_id'] = df7['auction_id'].astype(str)

# %%
df11 = df7.merge(df8, how='left', indicator=True)
df11
# Out:
#       auction_id                                          desc _merge
# 0         249841                              300 Bids Voucher   both
# 1         248449           Wii | Nintendo Console + Wii Sports   both
# 2         251844       Sony PlayStation 3 Slim 120GB + 50 Bids   both
# 3         251888                          Nokia N97 + 150 Bids   both
# 4         248432           Wii | Nintendo Console + Wii Sports   both
# ...          ...                                           ...    ...
# 54433     239387                               50 Bids Voucher   both
# 54434     240826         Microsoft Wireless Media Desktop 1000   both
# 54435     244697         Microsoft Wireless Media Desktop 1000   both
# 54436     249745                               50 Bids Voucher   both
# 54437     232588  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both
#
# [54438 rows x 3 columns]

# %%
gametype='game'
df11['stype']=gametype
df11
# Out:
#       auction_id                                          desc _merge stype
# 0         249841                              300 Bids Voucher   both  game
# 1         248449           Wii | Nintendo Console + Wii Sports   both  game
# 2         251844       Sony PlayStation 3 Slim 120GB + 50 Bids   both  game
# 3         251888                          Nokia N97 + 150 Bids   both  game
# 4         248432           Wii | Nintendo Console + Wii Sports   both  game
# ...          ...                                           ...    ...   ...
# 54433     239387                               50 Bids Voucher   both  game
# 54434     240826         Microsoft Wireless Media Desktop 1000   both  game
# 54435     244697         Microsoft Wireless Media Desktop 1000   both  game
# 54436     249745                               50 Bids Voucher   both  game
# 54437     232588  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both  game
#
# [54438 rows x 4 columns]

# %%
lifestype='game'
df11['lifestyle']=lifestype
df11.head()
# Out:
#   auction_id                                     desc _merge stype lifestyle
# 0     249841                         300 Bids Voucher   both  game      game
# 1     248449      Wii | Nintendo Console + Wii Sports   both  game      game
# 2     251844  Sony PlayStation 3 Slim 120GB + 50 Bids   both  game      game
# 3     251888                     Nokia N97 + 150 Bids   both  game      game
# 4     248432      Wii | Nintendo Console + Wii Sports   both  game      game

# %%
df11['reward']=df11['desc']
df11
# Out:
#       auction_id                                          desc _merge stype  \
# 0         249841                              300 Bids Voucher   both  game
# 1         248449           Wii | Nintendo Console + Wii Sports   both  game
# 2         251844       Sony PlayStation 3 Slim 120GB + 50 Bids   both  game
# 3         251888                          Nokia N97 + 150 Bids   both  game
# 4         248432           Wii | Nintendo Console + Wii Sports   both  game
# ...          ...                                           ...    ...   ...
# 54433     239387                               50 Bids Voucher   both  game
# 54434     240826         Microsoft Wireless Media Desktop 1000   both  game
# 54435     244697         Microsoft Wireless Media Desktop 1000   both  game
# 54436     249745                               50 Bids Voucher   both  game
# 54437     232588  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both  game
#
#       lifestyle                                        reward
# 0          game                              300 Bids Voucher
# 1          game           Wii | Nintendo Console + Wii Sports
# 2          game       Sony PlayStation 3 Slim 120GB + 50 Bids
# 3          game                          Nokia N97 + 150 Bids
# 4          game           Wii | Nintendo Console + Wii Sports
# ...         ...                                           ...
# 54433      game                               50 Bids Voucher
# 54434      game         Microsoft Wireless Media Desktop 1000
# 54435      game         Microsoft Wireless Media Desktop 1000
# 54436      game                               50 Bids Voucher
# 54437      game  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop
#
# [54438 rows x 6 columns]

# %%
linked='google.com'
df11['linked']=linked
df11
# Out:
#       auction_id                                          desc _merge stype  \
# 0         249841                              300 Bids Voucher   both  game
# 1         248449           Wii | Nintendo Console + Wii Sports   both  game
# 2         251844       Sony PlayStation 3 Slim 120GB + 50 Bids   both  game
# 3         251888                          Nokia N97 + 150 Bids   both  game
# 4         248432           Wii | Nintendo Console + Wii Sports   both  game
# ...          ...                                           ...    ...   ...
# 54433     239387                               50 Bids Voucher   both  game
# 54434     240826         Microsoft Wireless Media Desktop 1000   both  game
# 54435     244697         Microsoft Wireless Media Desktop 1000   both  game
# 54436     249745                               50 Bids Voucher   both  game
# 54437     232588  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both  game
#
#       lifestyle                                        reward      linked
# 0          game                              300 Bids Voucher  google.com
# 1          game           Wii | Nintendo Console + Wii Sports  google.com
# 2          game       Sony PlayStation 3 Slim 120GB + 50 Bids  google.com
# 3          game                          Nokia N97 + 150 Bids  google.com
# 4          game           Wii | Nintendo Console + Wii Sports  google.com
# ...         ...                                           ...         ...
# 54433      game                               50 Bids Voucher  google.com
# 54434      game         Microsoft Wireless Media Desktop 1000  google.com
# 54435      game         Microsoft Wireless Media Desktop 1000  google.com
# 54436      game                               50 Bids Voucher  google.com
# 54437      game  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop  google.com
#
# [54438 rows x 7 columns]

# %%
bracelet='[]'
df11['bracelet']=bracelet
df11
# Out:
#       auction_id                                          desc _merge stype  \
# 0         249841                              300 Bids Voucher   both  game
# 1         248449           Wii | Nintendo Console + Wii Sports   both  game
# 2         251844       Sony PlayStation 3 Slim 120GB + 50 Bids   both  game
# 3         251888                          Nokia N97 + 150 Bids   both  game
# 4         248432           Wii | Nintendo Console + Wii Sports   both  game
# ...          ...                                           ...    ...   ...
# 54433     239387                               50 Bids Voucher   both  game
# 54434     240826         Microsoft Wireless Media Desktop 1000   both  game
# 54435     244697         Microsoft Wireless Media Desktop 1000   both  game
# 54436     249745                               50 Bids Voucher   both  game
# 54437     232588  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both  game
#
#       lifestyle                                        reward      linked  \
# 0          game                              300 Bids Voucher  google.com
# 1          game           Wii | Nintendo Console + Wii Sports  google.com
# 2          game       Sony PlayStation 3 Slim 120GB + 50 Bids  google.com
# 3          game                          Nokia N97 + 150 Bids  google.com
# 4          game           Wii | Nintendo Console + Wii Sports  google.com
# ...         ...                                           ...         ...
# 54433      game                               50 Bids Voucher  google.com
# 54434      game         Microsoft Wireless Media Desktop 1000  google.com
# 54435      game         Microsoft Wireless Media Desktop 1000  google.com
# 54436      game                               50 Bids Voucher  google.com
# 54437      game  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop  google.com
#
#       bracelet
# 0           []
# 1           []
# 2           []
# 3           []
# 4           []
# ...        ...
# 54433       []
# 54434       []
# 54435       []
# 54436       []
# 54437       []
#
# [54438 rows x 8 columns]

# %%
df11=df11[['auction_id','stype','lifestyle','reward','desc','linked',	'bracelet']]
df11
# Out:
#       auction_id stype lifestyle  \
# 0         249841  game      game
# 1         248449  game      game
# 2         251844  game      game
# 3         251888  game      game
# 4         248432  game      game
# ...          ...   ...       ...
# 54433     239387  game      game
# 54434     240826  game      game
# 54435     244697  game      game
# 54436     249745  game      game
# 54437     232588  game      game
#
#                                              reward  \
# 0                                  300 Bids Voucher
# 1               Wii | Nintendo Console + Wii Sports
# 2           Sony PlayStation 3 Slim 120GB + 50 Bids
# 3                              Nokia N97 + 150 Bids
# 4               Wii | Nintendo Console + Wii Sports
# ...                                             ...
# 54433                               50 Bids Voucher
# 54434         Microsoft Wireless Media Desktop 1000
# 54435         Microsoft Wireless Media Desktop 1000
# 54436                               50 Bids Voucher
# 54437  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop
#
#                                                desc      linked bracelet
# 0                                  300 Bids Voucher  google.com       []
# 1               Wii | Nintendo Console + Wii Sports  google.com       []
# 2           Sony PlayStation 3 Slim 120GB + 50 Bids  google.com       []
# 3                              Nokia N97 + 150 Bids  google.com       []
# 4               Wii | Nintendo Console + Wii Sports  google.com       []
# ...                                             ...         ...      ...
# 54433                               50 Bids Voucher  google.com       []
# 54434         Microsoft Wireless Media Desktop 1000  google.com       []
# 54435         Microsoft Wireless Media Desktop 1000  google.com       []
# 54436                               50 Bids Voucher  google.com       []
# 54437  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop  google.com       []
#
# [54438 rows x 7 columns]

# %%
df11['braceletcopy']=df11['bracelet']
df11
# Out:
#       auction_id stype lifestyle  \
# 0         249841  game      game
# 1         248449  game      game
# 2         251844  game      game
# 3         251888  game      game
# 4         248432  game      game
# ...          ...   ...       ...
# 54433     239387  game      game
# 54434     240826  game      game
# 54435     244697  game      game
# 54436     249745  game      game
# 54437     232588  game      game
#
#                                              reward  \
# 0                                  300 Bids Voucher
# 1               Wii | Nintendo Console + Wii Sports
# 2           Sony PlayStation 3 Slim 120GB + 50 Bids
# 3                              Nokia N97 + 150 Bids
# 4               Wii | Nintendo Console + Wii Sports
# ...                                             ...
# 54433                               50 Bids Voucher
# 54434         Microsoft Wireless Media Desktop 1000
# 54435         Microsoft Wireless Media Desktop 1000
# 54436                               50 Bids Voucher
# 54437  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop
#
#                                                desc      linked bracelet  \
# 0                                  300 Bids Voucher  google.com       []
# 1               Wii | Nintendo Console + Wii Sports  google.com       []
# 2           Sony PlayStation 3 Slim 120GB + 50 Bids  google.com       []
# 3                              Nokia N97 + 150 Bids  google.com       []
# 4               Wii | Nintendo Console + Wii Sports  google.com       []
# ...                                             ...         ...      ...
# 54433                               50 Bids Voucher  google.com       []
# 54434         Microsoft Wireless Media Desktop 1000  google.com       []
# 54435         Microsoft Wireless Media Desktop 1000  google.com       []
# 54436                               50 Bids Voucher  google.com       []
# 54437  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop  google.com       []
#
#       braceletcopy
# 0               []
# 1               []
# 2               []
# 3               []
# 4               []
# ...            ...
# 54433           []
# 54434           []
# 54435           []
# 54436           []
# 54437           []
#
# [54438 rows x 8 columns]

# %%
df = pd.concat([df6, df11], ignore_index=True)

df
# Out:
#        auction_id stype lifestyle  \
# 0          249737   NaN       NaN
# 1          431265   NaN       NaN
# 2          470952   NaN       NaN
# 3          626545   NaN       NaN
# 4          944362   NaN       NaN
# ...           ...   ...       ...
# 289108     239387  game      game
# 289109     240826  game      game
# 289110     244697  game      game
# 289111     249745  game      game
# 289112     232588  game      game
#
#                                               reward  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 289108                               50 Bids Voucher
# 289109         Microsoft Wireless Media Desktop 1000
# 289110         Microsoft Wireless Media Desktop 1000
# 289111                               50 Bids Voucher
# 289112  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop
#
#                                                 desc      linked bracelet  \
# 0                                                NaN         NaN      NaN
# 1                                                NaN         NaN      NaN
# 2                                                NaN         NaN      NaN
# 3                                                NaN         NaN      NaN
# 4                                                NaN         NaN      NaN
# ...                                              ...         ...      ...
# 289108                               50 Bids Voucher  google.com       []
# 289109         Microsoft Wireless Media Desktop 1000  google.com       []
# 289110         Microsoft Wireless Media Desktop 1000  google.com       []
# 289111                               50 Bids Voucher  google.com       []
# 289112  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop  google.com       []
#
#        braceletcopy
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 289108           []
# 289109           []
# 289110           []
# 289111           []
# 289112           []
#
# [289113 rows x 8 columns]

# %%
df['stype'].fillna('game', inplace=True)
df['lifestyle'].fillna('game', inplace=True)
df['reward'].fillna('Wii | Nintendo Console + Wii Sports', inplace=True)
df['desc'].fillna('Wii | Nintendo Console + Wii Sports', inplace=True)
df['linked'].fillna('google.com', inplace=True)
df['bracelet'].fillna('[]', inplace=True)
df['braceletcopy'].fillna('[]', inplace=True)

# %%
df=df.drop_duplicates()
df
# Out:
#        auction_id stype lifestyle  \
# 0          249737  game      game
# 1          431265  game      game
# 2          470952  game      game
# 3          626545  game      game
# 4          944362  game      game
# ...           ...   ...       ...
# 288945     240944  game      game
# 288946     238907  game      game
# 288964     233461  game      game
# 288968     242583  game      game
# 289012     233332  game      game
#
#                                                    reward  \
# 0                     Wii | Nintendo Console + Wii Sports
# 1                     Wii | Nintendo Console + Wii Sports
# 2                     Wii | Nintendo Console + Wii Sports
# 3                     Wii | Nintendo Console + Wii Sports
# 4                     Wii | Nintendo Console + Wii Sports
# ...                                                   ...
# 288945                       Logitech G11 Gaming Keyboard
# 288946                        MySims Agents (Nintendo DS)
# 288964  Star Wars: The Clone Wars - Republic Heroes (Wii)
# 288968                               Dirt 2 (Nintendo DS)
# 289012                              FIFA 10 (Nintendo DS)
#
#                                                      desc      linked  \
# 0                     Wii | Nintendo Console + Wii Sports  google.com
# 1                     Wii | Nintendo Console + Wii Sports  google.com
# 2                     Wii | Nintendo Console + Wii Sports  google.com
# 3                     Wii | Nintendo Console + Wii Sports  google.com
# 4                     Wii | Nintendo Console + Wii Sports  google.com
# ...                                                   ...         ...
# 288945                       Logitech G11 Gaming Keyboard  google.com
# 288946                        MySims Agents (Nintendo DS)  google.com
# 288964  Star Wars: The Clone Wars - Republic Heroes (Wii)  google.com
# 288968                               Dirt 2 (Nintendo DS)  google.com
# 289012                              FIFA 10 (Nintendo DS)  google.com
#
#        bracelet braceletcopy
# 0            []           []
# 1            []           []
# 2            []           []
# 3            []           []
# 4            []           []
# ...         ...          ...
# 288945       []           []
# 288946       []           []
# 288964       []           []
# 288968       []           []
# 289012       []           []
#
# [208217 rows x 8 columns]

# %%
df.to_csv('newsVal.tsv',index=False,header=False,sep="\t")
