# %%
import pandas as pd
import numpy as np
import re

# %%
df=pd.read_csv('impression4 (2).csv')
df
# Out:
#     Unnamed: 0       bid_user         impressionTime  \
# 0            0   +34661281XXX  11/11/2019 9:05:58 AM
# 1            1  +441479812XXX  11/11/2019 9:05:58 AM
# 2            2  +441698293XXX  11/11/2019 9:05:58 AM
# 3            3  +441757291XXX  11/11/2019 9:05:58 AM
# 4            4  +441786449XXX  11/11/2019 9:05:58 AM
# ..         ...            ...                    ...
# 95          95       24091950  11/11/2019 9:05:58 AM
# 96          96       24133313  11/11/2019 9:05:58 AM
# 97          97       29061979  11/11/2019 9:05:58 AM
# 98          98      2broke2by  11/11/2019 9:05:58 AM
# 99          99   2cutenphilly  11/11/2019 9:05:58 AM
#
#                         history  \
# 0          224875 224929 223626
# 1                 227990 227988
# 2   225791 225811 225776 225803
# 3                        225801
# 4                 225803 225760
# ..                          ...
# 95                225903 225217
# 96         225844 226151 225896
# 97                       226148
# 98                       226162
# 99                225876 226009
#
#                                            impression
# 0   225739-1 160320-0 145816-0 214131-0 474704-0 1...
# 1   227878-0 859166-0 377596-0 707828-0 289374-0 6...
# 2   225793-0 783219-0 300805-0 437643-0 368991-0 2...
# 3   227994-0 272152-0 596477-0 774377-0 511686-0 7...
# 4   225773-0 360957-1 627339-0 993258-0 674175-0 7...
# ..                                                ...
# 95  226683-0 995177-0 512820-0 766745-0 668425-0 6...
# 96  226554-0 368336-0 394064-0 383055-0 819137-0 6...
# 97  228021-0 683662-0 594704-0 833115-0 355760-0 1...
# 98  226174-0 851438-0 684764-0 820432-0 340256-0 5...
# 99  226148-0 457009-0 549197-0 790774-0 765383-0 2...
#
# [100 rows x 5 columns]

# %%
df.to_csv('behaviors.tsv',index=False,header=False,sep="\t")

# %%
df2=df.impression
df2
# Out:
# 0     225739-1 160320-0 145816-0 214131-0 474704-0 1...
# 1     227878-0 859166-0 377596-0 707828-0 289374-0 6...
# 2     225793-0 783219-0 300805-0 437643-0 368991-0 2...
# 3     227994-0 272152-0 596477-0 774377-0 511686-0 7...
# 4     225773-0 360957-1 627339-0 993258-0 674175-0 7...
#                             ...
# 95    226683-0 995177-0 512820-0 766745-0 668425-0 6...
# 96    226554-0 368336-0 394064-0 383055-0 819137-0 6...
# 97    228021-0 683662-0 594704-0 833115-0 355760-0 1...
# 98    226174-0 851438-0 684764-0 820432-0 340256-0 5...
# 99    226148-0 457009-0 549197-0 790774-0 765383-0 2...
# Name: impression, Length: 100, dtype: object

# %%
def split_and_flatten(row):
    impressions = row['impression'].split()
    flattened = [item.split('-')[0] for item in impressions]
    return ' '.join(flattened)


df['new_dataset'] = df.apply(split_and_flatten, axis=1)


print(df[['new_dataset']])
# Out:
#                                           new_dataset
# 0   225739 160320 145816 214131 474704 101274 1850...
# 1   227878 859166 377596 707828 289374 655033 9761...
# 2   225793 783219 300805 437643 368991 260490 9410...
# 3   227994 272152 596477 774377 511686 726329 6806...
# 4   225773 360957 627339 993258 674175 755488 6416...
# ..                                                ...
# 95  226683 995177 512820 766745 668425 621420 5664...
# 96  226554 368336 394064 383055 819137 630917 3714...
# 97  228021 683662 594704 833115 355760 148008 5824...
# 98  226174 851438 684764 820432 340256 592150 1361...
# 99  226148 457009 549197 790774 765383 273631 2388...
#
# [100 rows x 1 columns]

# %%
new_df = df['new_dataset'].str.split().explode().reset_index(drop=True)

new_df = new_df.rename('split_values')


df6 = pd.DataFrame({'auction_id': new_df})


print(df6)
# Out:
#      auction_id
# 0        225739
# 1        160320
# 2        145816
# 3        214131
# 4        474704
# ...         ...
# 2095     822604
# 2096     384963
# 2097     856420
# 2098     241602
# 2099     351579
#
# [2100 rows x 1 columns]

# %%
df5=pd.read_csv('df11 (3).csv')
df5
# Out:
#      Unnamed: 0  auction_id stype lifestyle  \
# 0         99379      222661  game      game
# 1         99790      223626  game      game
# 2        100732      224875  game      game
# 3        100757      224909  game      game
# 4        100777      224929  game      game
# ..          ...         ...   ...       ...
# 288      120304      255483  game      game
# 289      120775      256076  game      game
# 290      121099      256602  game      game
# 291      121397      259038  game      game
# 292      121415      259066  game      game
#
#                                            reward  \
# 0                                 50 Bids Voucher
# 1         Sony PlayStation 3 Slim Console (120GB)
# 2                            Nokia N97 (Unlocked)
# 3            Apple iMac MB418LL/A 24-Inch Desktop
# 4    Apple MacBook Pro MB991LL/A 13.3-Inch Laptop
# ..                                            ...
# 288                  Nintendo DSi Console (Black)
# 289              Need For Speed: Shift (Xbox 360)
# 290           Wii | Nintendo Console + Wii Sports
# 291                               50 Bids Voucher
# 292                              300 Bids Voucher
#
#                                              desc      linked bracelet  \
# 0                                 50 Bids Voucher  google.com       []
# 1         Sony PlayStation 3 Slim Console (120GB)  google.com       []
# 2                            Nokia N97 (Unlocked)  google.com       []
# 3            Apple iMac MB418LL/A 24-Inch Desktop  google.com       []
# 4    Apple MacBook Pro MB991LL/A 13.3-Inch Laptop  google.com       []
# ..                                            ...         ...      ...
# 288                  Nintendo DSi Console (Black)  google.com       []
# 289              Need For Speed: Shift (Xbox 360)  google.com       []
# 290           Wii | Nintendo Console + Wii Sports  google.com       []
# 291                               50 Bids Voucher  google.com       []
# 292                              300 Bids Voucher  google.com       []
#
#     braceletcopy
# 0             []
# 1             []
# 2             []
# 3             []
# 4             []
# ..           ...
# 288           []
# 289           []
# 290           []
# 291           []
# 292           []
#
# [293 rows x 9 columns]

# %%
df = pd.concat([df6, df5], ignore_index=True)

df
# Out:
#      auction_id  Unnamed: 0 stype lifestyle  \
# 0        225739         NaN   NaN       NaN
# 1        160320         NaN   NaN       NaN
# 2        145816         NaN   NaN       NaN
# 3        214131         NaN   NaN       NaN
# 4        474704         NaN   NaN       NaN
# ...         ...         ...   ...       ...
# 2388     255483    120304.0  game      game
# 2389     256076    120775.0  game      game
# 2390     256602    121099.0  game      game
# 2391     259038    121397.0  game      game
# 2392     259066    121415.0  game      game
#
#                                    reward  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 2388         Nintendo DSi Console (Black)
# 2389     Need For Speed: Shift (Xbox 360)
# 2390  Wii | Nintendo Console + Wii Sports
# 2391                      50 Bids Voucher
# 2392                     300 Bids Voucher
#
#                                      desc      linked bracelet braceletcopy
# 0                                     NaN         NaN      NaN          NaN
# 1                                     NaN         NaN      NaN          NaN
# 2                                     NaN         NaN      NaN          NaN
# 3                                     NaN         NaN      NaN          NaN
# 4                                     NaN         NaN      NaN          NaN
# ...                                   ...         ...      ...          ...
# 2388         Nintendo DSi Console (Black)  google.com       []           []
# 2389     Need For Speed: Shift (Xbox 360)  google.com       []           []
# 2390  Wii | Nintendo Console + Wii Sports  google.com       []           []
# 2391                      50 Bids Voucher  google.com       []           []
# 2392                     300 Bids Voucher  google.com       []           []
#
# [2393 rows x 9 columns]

# %%
df['Unnamed: 0'].fillna(pd.Series(np.random.randint(100000, 999999, size=len(df), dtype='int'), dtype='int'), inplace=True)
df['stype'].fillna('game', inplace=True)
df['lifestyle'].fillna('game', inplace=True)
df['reward'].fillna('Wii | Nintendo Console + Wii Sports', inplace=True)
df['desc'].fillna('Wii | Nintendo Console + Wii Sports', inplace=True)
df['linked'].fillna('google.com', inplace=True)
df['bracelet'].fillna('[]', inplace=True)
df['braceletcopy'].fillna('[]', inplace=True)

# %%
df=df[['Unnamed: 0','auction_id',	'stype',	'lifestyle',	'reward',	'desc',	'linked',	'bracelet',	'braceletcopy']]
df
# Out:
#       Unnamed: 0 auction_id stype lifestyle  \
# 0       861293.0     225739  game      game
# 1       519067.0     160320  game      game
# 2       212897.0     145816  game      game
# 3       764169.0     214131  game      game
# 4       406562.0     474704  game      game
# ...          ...        ...   ...       ...
# 2388    120304.0     255483  game      game
# 2389    120775.0     256076  game      game
# 2390    121099.0     256602  game      game
# 2391    121397.0     259038  game      game
# 2392    121415.0     259066  game      game
#
#                                    reward  \
# 0     Wii | Nintendo Console + Wii Sports
# 1     Wii | Nintendo Console + Wii Sports
# 2     Wii | Nintendo Console + Wii Sports
# 3     Wii | Nintendo Console + Wii Sports
# 4     Wii | Nintendo Console + Wii Sports
# ...                                   ...
# 2388         Nintendo DSi Console (Black)
# 2389     Need For Speed: Shift (Xbox 360)
# 2390  Wii | Nintendo Console + Wii Sports
# 2391                      50 Bids Voucher
# 2392                     300 Bids Voucher
#
#                                      desc      linked bracelet braceletcopy
# 0     Wii | Nintendo Console + Wii Sports  google.com       []           []
# 1     Wii | Nintendo Console + Wii Sports  google.com       []           []
# 2     Wii | Nintendo Console + Wii Sports  google.com       []           []
# 3     Wii | Nintendo Console + Wii Sports  google.com       []           []
# 4     Wii | Nintendo Console + Wii Sports  google.com       []           []
# ...                                   ...         ...      ...          ...
# 2388         Nintendo DSi Console (Black)  google.com       []           []
# 2389     Need For Speed: Shift (Xbox 360)  google.com       []           []
# 2390  Wii | Nintendo Console + Wii Sports  google.com       []           []
# 2391                      50 Bids Voucher  google.com       []           []
# 2392                     300 Bids Voucher  google.com       []           []
#
# [2393 rows x 9 columns]

# %%
df.set_index('Unnamed: 0', inplace=True)
df
# Out:
#            auction_id stype lifestyle                               reward  \
# Unnamed: 0
# 861293.0       225739  game      game  Wii | Nintendo Console + Wii Sports
# 519067.0       160320  game      game  Wii | Nintendo Console + Wii Sports
# 212897.0       145816  game      game  Wii | Nintendo Console + Wii Sports
# 764169.0       214131  game      game  Wii | Nintendo Console + Wii Sports
# 406562.0       474704  game      game  Wii | Nintendo Console + Wii Sports
# ...               ...   ...       ...                                  ...
# 120304.0       255483  game      game         Nintendo DSi Console (Black)
# 120775.0       256076  game      game     Need For Speed: Shift (Xbox 360)
# 121099.0       256602  game      game  Wii | Nintendo Console + Wii Sports
# 121397.0       259038  game      game                      50 Bids Voucher
# 121415.0       259066  game      game                     300 Bids Voucher
#
#                                            desc      linked bracelet  \
# Unnamed: 0
# 861293.0    Wii | Nintendo Console + Wii Sports  google.com       []
# 519067.0    Wii | Nintendo Console + Wii Sports  google.com       []
# 212897.0    Wii | Nintendo Console + Wii Sports  google.com       []
# 764169.0    Wii | Nintendo Console + Wii Sports  google.com       []
# 406562.0    Wii | Nintendo Console + Wii Sports  google.com       []
# ...                                         ...         ...      ...
# 120304.0           Nintendo DSi Console (Black)  google.com       []
# 120775.0       Need For Speed: Shift (Xbox 360)  google.com       []
# 121099.0    Wii | Nintendo Console + Wii Sports  google.com       []
# 121397.0                        50 Bids Voucher  google.com       []
# 121415.0                       300 Bids Voucher  google.com       []
#
#            braceletcopy
# Unnamed: 0
# 861293.0             []
# 519067.0             []
# 212897.0             []
# 764169.0             []
# 406562.0             []
# ...                 ...
# 120304.0             []
# 120775.0             []
# 121099.0             []
# 121397.0             []
# 121415.0             []
#
# [2393 rows x 8 columns]

# %%
df.index = df.index.astype(int)
df
# Out:
#        auction_id stype lifestyle                               reward  \
# 861293     225739  game      game  Wii | Nintendo Console + Wii Sports
# 519067     160320  game      game  Wii | Nintendo Console + Wii Sports
# 212897     145816  game      game  Wii | Nintendo Console + Wii Sports
# 764169     214131  game      game  Wii | Nintendo Console + Wii Sports
# 406562     474704  game      game  Wii | Nintendo Console + Wii Sports
# ...           ...   ...       ...                                  ...
# 121099     256602  game      game  Wii | Nintendo Console + Wii Sports
# 121397     259038  game      game                      50 Bids Voucher
# 121415     259066  game      game                     300 Bids Voucher
# 0          227981  game      game                     300 Bids Voucher
# 0          225231  game      game                     300 Bids Voucher
#
#                                        desc      linked bracelet braceletcopy
# 861293  Wii | Nintendo Console + Wii Sports  google.com       []           []
# 519067  Wii | Nintendo Console + Wii Sports  google.com       []           []
# 212897  Wii | Nintendo Console + Wii Sports  google.com       []           []
# 764169  Wii | Nintendo Console + Wii Sports  google.com       []           []
# 406562  Wii | Nintendo Console + Wii Sports  google.com       []           []
# ...                                     ...         ...      ...          ...
# 121099  Wii | Nintendo Console + Wii Sports  google.com       []           []
# 121397                      50 Bids Voucher  google.com       []           []
# 121415                     300 Bids Voucher  google.com       []           []
# 0                          300 Bids Voucher  google.com       []           []
# 0                          300 Bids Voucher  google.com       []           []
#
# [2395 rows x 8 columns]

# %%
new = ['227981',	'game',	'game',	'300 Bids Voucher',	'300 Bids Voucher',	'google.com','[]','[]']
new = pd.DataFrame(columns=df.columns, data=[new])
df = pd.concat([df, new], axis=0)

# %%
new1 = ['225231',	'game',	'game',	'300 Bids Voucher',	'300 Bids Voucher',	'google.com','[]','[]']
new1 = pd.DataFrame(columns=df.columns, data=[new1])
df = pd.concat([df, new1], axis=0)

# %%
df.to_csv('df11.tsv',index=False,header=False,sep="\t")

# %%
df11=pd.read_csv('news.tsv',sep="\t")
df11
# Out:
#       214131  game game.1  Wii | Nintendo Console + Wii Sports  \
# 0     474704  game   game  Wii | Nintendo Console + Wii Sports
# 1     101274  game   game  Wii | Nintendo Console + Wii Sports
# 2     185047  game   game  Wii | Nintendo Console + Wii Sports
# 3     406094  game   game  Wii | Nintendo Console + Wii Sports
# 4     431764  game   game  Wii | Nintendo Console + Wii Sports
# ...      ...   ...    ...                                  ...
# 2392  225739  game   game                     300 Bids Voucher
# 2393  160320  game   game                     300 Bids Voucher
# 2394  145816  game   game                     300 Bids Voucher
# 2395  226112  game   game                     300 Bids Voucher
# 2396  226113  game   game                     300 Bids Voucher
#
#      Wii | Nintendo Console + Wii Sports.1  google.com  [] [].1
# 0      Wii | Nintendo Console + Wii Sports  google.com  []   []
# 1      Wii | Nintendo Console + Wii Sports  google.com  []   []
# 2      Wii | Nintendo Console + Wii Sports  google.com  []   []
# 3      Wii | Nintendo Console + Wii Sports  google.com  []   []
# 4      Wii | Nintendo Console + Wii Sports  google.com  []   []
# ...                                    ...         ...  ..  ...
# 2392                      300 Bids Voucher  google.com  []   []
# 2393                      300 Bids Voucher  google.com  []   []
# 2394                      300 Bids Voucher  google.com  []   []
# 2395                      300 Bids Voucher  google.com  []   []
# 2396                      300 Bids Voucher  google.com  []   []
#
# [2397 rows x 8 columns]

# %%
new2= ['226113',	'game',	'game',	'300 Bids Voucher',	'300 Bids Voucher',	'google.com','[]','[]']
new2 = pd.DataFrame(columns=df11.columns, data=[new2])
df11 = pd.concat([df11, new2], axis=0)

# %%
new3= ['145816',	'game',	'game',	'300 Bids Voucher',	'300 Bids Voucher',	'google.com','[]','[]']
new3 = pd.DataFrame(columns=df11.columns, data=[new3])
df11 = pd.concat([df11, new3], axis=0)

# %%
new4= ['160320',	'game',	'game',	'300 Bids Voucher',	'300 Bids Voucher',	'google.com','[]','[]']
new4 = pd.DataFrame(columns=df11.columns, data=[new4])
df11 = pd.concat([df11, new4], axis=0)

# %%
df11.to_csv('news.tsv',index=False,sep="\t")

# %%
columns_name =['index', 'userID','time', 'occurence', 'history']
df=pd.read_csv('behaviors.tsv',sep="\t",names=columns_name)
df
# Out:
#     index         userID                   time                    occurence  \
# 0       0   +34661281XXX  11/11/2019 9:05:58 AM         224875 224929 223626
# 1       1  +441479812XXX  11/11/2019 9:05:58 AM                227990 227988
# 2       2  +441698293XXX  11/11/2019 9:05:58 AM  225791 225811 225776 225803
# 3       3  +441757291XXX  11/11/2019 9:05:58 AM                       225801
# 4       4  +441786449XXX  11/11/2019 9:05:58 AM                225803 225760
# ..    ...            ...                    ...                          ...
# 95     95       24091950  11/11/2019 9:05:58 AM                225903 225217
# 96     96       24133313  11/11/2019 9:05:58 AM         225844 226151 225896
# 97     97       29061979  11/11/2019 9:05:58 AM                       226148
# 98     98      2broke2by  11/11/2019 9:05:58 AM                       226162
# 99     99   2cutenphilly  11/11/2019 9:05:58 AM                225876 226009
#
#                                               history
# 0   225739-1 160320-0 145816-0 214131-0 474704-0 1...
# 1   227878-0 859166-0 377596-0 707828-0 289374-0 6...
# 2   225793-0 783219-0 300805-0 437643-0 368991-0 2...
# 3   227994-0 272152-0 596477-0 774377-0 511686-0 7...
# 4   225773-0 360957-1 627339-0 993258-0 674175-0 7...
# ..                                                ...
# 95  226683-0 995177-0 512820-0 766745-0 668425-0 6...
# 96  226554-0 368336-0 394064-0 383055-0 819137-0 6...
# 97  228021-0 683662-0 594704-0 833115-0 355760-0 1...
# 98  226174-0 851438-0 684764-0 820432-0 340256-0 5...
# 99  226148-0 457009-0 549197-0 790774-0 765383-0 2...
#
# [100 rows x 5 columns]

# %%
df2=df.occurence
df2
# Out:
# 0            224875 224929 223626
# 1                   227990 227988
# 2     225791 225811 225776 225803
# 3                          225801
# 4                   225803 225760
#                  ...
# 95                  225903 225217
# 96           225844 226151 225896
# 97                         226148
# 98                         226162
# 99                  225876 226009
# Name: occurence, Length: 100, dtype: object

# %%
df2.columns =['new_dataset']
df2
# Out:
# 0            224875 224929 223626
# 1                   227990 227988
# 2     225791 225811 225776 225803
# 3                          225801
# 4                   225803 225760
#                  ...
# 95                  225903 225217
# 96           225844 226151 225896
# 97                         226148
# 98                         226162
# 99                  225876 226009
# Name: occurence, Length: 100, dtype: object

# %%
new_df = df2.str.split().explode()

new_df = new_df.rename('split_values')


df6 = pd.DataFrame({'auction_id': new_df})


print(df6)
# Out:
#    auction_id
# 0      224875
# 0      224929
# 0      223626
# 1      227990
# 1      227988
# ..        ...
# 96     225896
# 97     226148
# 98     226162
# 99     225876
# 99     226009
#
# [390 rows x 1 columns]

# %%
columns_name =['auction_id', 'style','style2', 'style3', 'style4','style5', 'style6','styole7']
df=pd.read_csv('news (2).tsv',sep='\t',names=columns_name)
df
# Out:
#       auction_id style style2                               style3  \
# 0         224875  game   game  Wii | Nintendo Console + Wii Sports
# 1         224929  game   game  Wii | Nintendo Console + Wii Sports
# 2         223626  game   game  Wii | Nintendo Console + Wii Sports
# 3         227990  game   game  Wii | Nintendo Console + Wii Sports
# 4         227988  game   game  Wii | Nintendo Console + Wii Sports
# ...          ...   ...    ...                                  ...
# 2783      225739  game   game                     300 Bids Voucher
# 2784      160320  game   game                     300 Bids Voucher
# 2785      145816  game   game                     300 Bids Voucher
# 2786      226112  game   game                     300 Bids Voucher
# 2787      226113  game   game                     300 Bids Voucher
#
#                                    style4      style5 style6 styole7
# 0     Wii | Nintendo Console + Wii Sports  google.com     []      []
# 1     Wii | Nintendo Console + Wii Sports  google.com     []      []
# 2     Wii | Nintendo Console + Wii Sports  google.com     []      []
# 3     Wii | Nintendo Console + Wii Sports  google.com     []      []
# 4     Wii | Nintendo Console + Wii Sports  google.com     []      []
# ...                                   ...         ...    ...     ...
# 2783                     300 Bids Voucher  google.com     []      []
# 2784                     300 Bids Voucher  google.com     []      []
# 2785                     300 Bids Voucher  google.com     []      []
# 2786                     300 Bids Voucher  google.com     []      []
# 2787                     300 Bids Voucher  google.com     []      []
#
# [2788 rows x 8 columns]

# %%
df = pd.concat([df6, df], ignore_index=True)

df
# Out:
#      auction_id style style2            style3            style4      style5  \
# 0        224875   NaN    NaN               NaN               NaN         NaN
# 1        224929   NaN    NaN               NaN               NaN         NaN
# 2        223626   NaN    NaN               NaN               NaN         NaN
# 3        227990   NaN    NaN               NaN               NaN         NaN
# 4        227988   NaN    NaN               NaN               NaN         NaN
# ...         ...   ...    ...               ...               ...         ...
# 2783     225739  game   game  300 Bids Voucher  300 Bids Voucher  google.com
# 2784     160320  game   game  300 Bids Voucher  300 Bids Voucher  google.com
# 2785     145816  game   game  300 Bids Voucher  300 Bids Voucher  google.com
# 2786     226112  game   game  300 Bids Voucher  300 Bids Voucher  google.com
# 2787     226113  game   game  300 Bids Voucher  300 Bids Voucher  google.com
#
#      style6 styole7
# 0       NaN     NaN
# 1       NaN     NaN
# 2       NaN     NaN
# 3       NaN     NaN
# 4       NaN     NaN
# ...     ...     ...
# 2783     []      []
# 2784     []      []
# 2785     []      []
# 2786     []      []
# 2787     []      []
#
# [2788 rows x 8 columns]

# %%
df['style'].fillna('game', inplace=True)
df['style2'].fillna('game', inplace=True)
df['style3'].fillna('Wii | Nintendo Console + Wii Sports', inplace=True)
df['style4'].fillna('Wii | Nintendo Console + Wii Sports', inplace=True)
df['style5'].fillna('google.com', inplace=True)
df['style6'].fillna('[]', inplace=True)
df['styole7'].fillna('[]', inplace=True)

# %%
display(df.drop_duplicates())
# Out:
#       auction_id style style2                               style3  \
# 0         224875  game   game  Wii | Nintendo Console + Wii Sports
# 1         224929  game   game  Wii | Nintendo Console + Wii Sports
# 2         223626  game   game  Wii | Nintendo Console + Wii Sports
# 3         227990  game   game  Wii | Nintendo Console + Wii Sports
# 4         227988  game   game  Wii | Nintendo Console + Wii Sports
# ...          ...   ...    ...                                  ...
# 2783      225739  game   game                     300 Bids Voucher
# 2784      160320  game   game                     300 Bids Voucher
# 2785      145816  game   game                     300 Bids Voucher
# 2786      226112  game   game                     300 Bids Voucher
# 2787      226113  game   game                     300 Bids Voucher
#
#                                    style4      style5 style6 styole7
# 0     Wii | Nintendo Console + Wii Sports  google.com     []      []
# 1     Wii | Nintendo Console + Wii Sports  google.com     []      []
# 2     Wii | Nintendo Console + Wii Sports  google.com     []      []
# 3     Wii | Nintendo Console + Wii Sports  google.com     []      []
# 4     Wii | Nintendo Console + Wii Sports  google.com     []      []
# ...                                   ...         ...    ...     ...
# 2783                     300 Bids Voucher  google.com     []      []
# 2784                     300 Bids Voucher  google.com     []      []
# 2785                     300 Bids Voucher  google.com     []      []
# 2786                     300 Bids Voucher  google.com     []      []
# 2787                     300 Bids Voucher  google.com     []      []
#
# [2646 rows x 8 columns]

# %%
df.to_csv('news.tsv',index=False,header=False,sep="\t")
