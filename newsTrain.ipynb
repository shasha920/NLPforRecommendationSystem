# %%
import pandas as pd
import numpy as np
import re

# %%
columns_name =['bid_user','impressionTime','history','impression']
df=pd.read_csv('behaviorTrain_data.tsv',sep="\t",names=columns_name)
df
# Out:
#              bid_user         impressionTime  \
# 33213       Theking74  11/11/2019 9:05:58 AM
# 18089         Kino555  11/11/2019 9:05:58 AM
# 19716          Lmitch  11/11/2019 9:05:58 AM
# 9456        Dooby2008  11/11/2019 9:05:58 AM
# 8921      Digitalfail  11/11/2019 9:05:58 AM
# ...               ...                    ...
# 16734          Joyces  11/11/2019 9:05:58 AM
# 16304    Joaniecheney  11/11/2019 9:05:58 AM
# 79     +4917641092XXX  11/11/2019 9:05:58 AM
# 12119         Gcougar  11/11/2019 9:05:58 AM
# 14147       Hollyface  11/11/2019 9:05:58 AM
#
#                                                  history  \
# 33213  225354 226994 226149 240824 240589 239466 2389...
# 18089  244553 243420 242878 243443 243444 243453 2434...
# 19716                               248783 251823 248780
# 9456                         248638 248636 251879 250292
# 8921                                       249881 249802
# ...                                                  ...
# ...

# %%
df2=df.impression
df2
# Out:
# 33213    244829-0 779670-0 880354-1 739054-0 180993-0 6...
# 18089    257041-1 283585-0 313694-0 496357-0 187411-0 2...
# 19716    256471-0 690817-0 756461-0 307002-0 999342-0 8...
# 9456     252600-0 419830-0 689837-0 267631-0 328955-0 8...
# 8921     249890-0 976267-0 343406-1 163124-0 158218-0 7...
#                                ...
# 16734    255836-0 427532-0 527503-0 325639-0 658778-0 3...
# 16304    234029-0 390384-0 935070-0 535074-0 758450-0 6...
# 79       253403-0 597152-0 207281-0 533323-0 745572-0 5...
# 12119    233541-0 606151-0 924520-0 830125-0 534358-0 7...
# 14147    251879-0 426589-0 593502-0 949383-0 116076-0 7...
# Name: impression, Length: 26074, dtype: object

# %%
def split_and_flatten(row):
    impressions = row['impression'].split()
    flattened = [item.split('-')[0] for item in impressions]
    return ' '.join(flattened)


df['new_dataset'] = df.apply(split_and_flatten, axis=1)


print(df[['new_dataset']])
# Out:
#                                              new_dataset
# 33213  244829 779670 880354 739054 180993 678681 1746...
# 18089  257041 283585 313694 496357 187411 203686 5078...
# 19716  256471 690817 756461 307002 999342 883975 8837...
# 9456   252600 419830 689837 267631 328955 878451 2869...
# 8921   249890 976267 343406 163124 158218 705740 3406...
# ...                                                  ...
# 16734  255836 427532 527503 325639 658778 318123 5320...
# 16304  234029 390384 935070 535074 758450 680833 4317...
# 79     253403 597152 207281 533323 745572 572447 8321...
# 12119  233541 606151 924520 830125 534358 753156 3159...
# 14147  251879 426589 593502 949383 116076 787568 3302...
#
# [26074 rows x 1 columns]

# %%
new_df = df['new_dataset'].str.split().explode().reset_index(drop=True)

new_df = new_df.rename('split_values')


df6 = pd.DataFrame({'auction_id': new_df})


print(df6)
# Out:
#        auction_id
# 0          244829
# 1          779670
# 2          880354
# 3          739054
# 4          180993
# ...           ...
# 547549     770434
# 547550     457355
# 547551     265777
# 547552     681833
# 547553     265225
#
# [547554 rows x 1 columns]

# %%
df7=df.history
df7
# Out:
# 33213    225354 226994 226149 240824 240589 239466 2389...
# 18089    244553 243420 242878 243443 243444 243453 2434...
# 19716                                 248783 251823 248780
# 9456                           248638 248636 251879 250292
# 8921                                         249881 249802
#                                ...
# 16734                                 225844 229933 243139
# 16304                                 232607 232614 232606
# 79                                                  250144
# 12119                                               231048
# 14147                                               246987
# Name: history, Length: 26074, dtype: object

# %%
df7.columns =['new_datasets']
df7
# Out:
# 33213    225354 226994 226149 240824 240589 239466 2389...
# 18089    244553 243420 242878 243443 243444 243453 2434...
# 19716                                 248783 251823 248780
# 9456                           248638 248636 251879 250292
# 8921                                         249881 249802
#                                ...
# 16734                                 225844 229933 243139
# 16304                                 232607 232614 232606
# 79                                                  250144
# 12119                                               231048
# 14147                                               246987
# Name: history, Length: 26074, dtype: object

# %%
new_df = df7.str.split().explode()

new_df = new_df.rename('split_values')


df7 = pd.DataFrame({'auction_id': new_df})

print(df7)
# Out:
#       auction_id
# 33213     225354
# 33213     226994
# 33213     226149
# 33213     240824
# 33213     240589
# ...          ...
# 16304     232614
# 16304     232606
# 79        250144
# 12119     231048
# 14147     246987
#
# [130955 rows x 1 columns]

# %%
df7.reset_index(drop=True, inplace=True)
df7
# Out:
#        auction_id
# 0          225354
# 1          226994
# 2          226149
# 3          240824
# 4          240589
# ...           ...
# 130950     232614
# 130951     232606
# 130952     250144
# 130953     231048
# 130954     246987
#
# [130955 rows x 1 columns]

# %%
df7.dtypes
# Out:
# auction_id    object
# dtype: object

# %%
df1=pd.read_table('outcomes.tsv')
df1.head()
# Out:
#    auction_id  product_id                                      item  \
# 0       86827    10009602  sony-ericsson-s500i-unlocked-mysterious-
# 1       87964    10009881            psp-slim-lite-sony-piano-black
# 2       87965    10009881            psp-slim-lite-sony-piano-black
# 3       88638    10006115  sony-ericsson-s500i-unlocked-mysterious-
# 4       88639    10006115  sony-ericsson-s500i-unlocked-mysterious-
#
#                                             desc  retail  price  finalprice  \
# 0  Sony Ericsson S500i Unlocked Mysterious Green  499.99  13.35       13.35
# 1               PSP Slim & Lite Sony Piano Black  169.99  74.70       74.70
# 2               PSP Slim & Lite Sony Piano Black  169.99  83.10       83.10
# 3  Sony Ericsson S500i Unlocked Mysterious Green  499.99  19.65       19.65
# 4  Sony Ericsson S500i Unlocked Mysterious Green  499.99  47.10       47.10
#
#    bidincrement  bidfee        winner  placedbids  freebids  \
# ...

# %%
df8=df1.drop(['product_id','item','retail','price','finalprice','bidincrement','bidfee','winner','placedbids','freebids','endtime_str','flg_click_only','flg_beginnerauction','flg_fixedprice','flg_endprice'],axis='columns')
df8
# Out:
#         auction_id                                           desc
# 0            86827  Sony Ericsson S500i Unlocked Mysterious Green
# 1            87964               PSP Slim & Lite Sony Piano Black
# 2            87965               PSP Slim & Lite Sony Piano Black
# 3            88638  Sony Ericsson S500i Unlocked Mysterious Green
# 4            88639  Sony Ericsson S500i Unlocked Mysterious Green
# ...            ...                                            ...
# 121414      259065                               300 Bids Voucher
# 121415      259066                               300 Bids Voucher
# 121416      259068                               300 Bids Voucher
# 121417      259069                               300 Bids Voucher
# 121418      259070                               300 Bids Voucher
#
# [121419 rows x 2 columns]

# %%
df8.auction_id.dtypes
# Out:
# dtype('int64')

# %%
#df11=df8.loc[df8.auction_id.isin(df7.auction_id)]
#df11
# Out:
#         auction_id                                          desc
# 99110       222389       Guitar Hero World Tour Guitar Kit (Wii)
# 99115       222394  Guitar Hero World Tour Guitar Kit (Xbox 360)
# 99116       222395  Guitar Hero World Tour Guitar Kit (Xbox 360)
# 99165       222444                          The Reader [Blu-ray]
# 99185       222464      Professor Layton and the Curious Village
# ...            ...                                           ...
# 121407      259058                              300 Bids Voucher
# 121408      259059                              300 Bids Voucher
# 121412      259063                              300 Bids Voucher
# 121414      259065                              300 Bids Voucher
# 121415      259066                              300 Bids Voucher
#
# [3050 rows x 2 columns]

# %%
df8['auction_id'] = df8['auction_id'].astype(str)
df7['auction_id'] = df7['auction_id'].astype(str)

# %%
df11 = df7.merge(df8, how='left', indicator=True)
df11
# Out:
#        auction_id                                             desc _merge
# 0          225354  JBL Control 2.4G On Air Wireless Speaker System   both
# 1          226994                          Halo 3: ODST (Xbox 360)   both
# 2          226149                                 300 Bids Voucher   both
# 3          240824            Microsoft Wireless Media Desktop 1000   both
# 4          240589                 Microsoft Windows 7 Home Premium   both
# ...           ...                                              ...    ...
# 130950     232614     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both
# 130951     232606     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both
# 130952     250144     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both
# 130953     231048          Sony PlayStation 3 Slim Console (120GB)   both
# 130954     246987          Sony PlayStation 3 Slim Console (120GB)   both
#
# [130955 rows x 3 columns]

# %%
gametype='game'
df11['stype']=gametype
df11
# Out:
#        auction_id                                             desc _merge  \
# 0          225354  JBL Control 2.4G On Air Wireless Speaker System   both
# 1          226994                          Halo 3: ODST (Xbox 360)   both
# 2          226149                                 300 Bids Voucher   both
# 3          240824            Microsoft Wireless Media Desktop 1000   both
# 4          240589                 Microsoft Windows 7 Home Premium   both
# ...           ...                                              ...    ...
# 130950     232614     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both
# 130951     232606     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both
# 130952     250144     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both
# 130953     231048          Sony PlayStation 3 Slim Console (120GB)   both
# 130954     246987          Sony PlayStation 3 Slim Console (120GB)   both
#
#        stype
# 0       game
# 1       game
# 2       game
# 3       game
# ...

# %%
lifestype='game'
df11['lifestyle']=lifestype
df11.head()
# Out:
#   auction_id                                             desc _merge stype  \
# 0     225354  JBL Control 2.4G On Air Wireless Speaker System   both  game
# 1     226994                          Halo 3: ODST (Xbox 360)   both  game
# 2     226149                                 300 Bids Voucher   both  game
# 3     240824            Microsoft Wireless Media Desktop 1000   both  game
# 4     240589                 Microsoft Windows 7 Home Premium   both  game
#
#   lifestyle
# 0      game
# 1      game
# 2      game
# 3      game
# 4      game

# %%
df11['reward']=df11['desc']
df11
# Out:
#        auction_id                                             desc _merge  \
# 0          225354  JBL Control 2.4G On Air Wireless Speaker System   both
# 1          226994                          Halo 3: ODST (Xbox 360)   both
# 2          226149                                 300 Bids Voucher   both
# 3          240824            Microsoft Wireless Media Desktop 1000   both
# 4          240589                 Microsoft Windows 7 Home Premium   both
# ...           ...                                              ...    ...
# 130950     232614     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both
# 130951     232606     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both
# 130952     250144     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both
# 130953     231048          Sony PlayStation 3 Slim Console (120GB)   both
# 130954     246987          Sony PlayStation 3 Slim Console (120GB)   both
#
#        stype lifestyle                                           reward
# ...

# %%
linked='google.com'
df11['linked']=linked
df11
# Out:
#        auction_id                                             desc _merge  \
# 0          225354  JBL Control 2.4G On Air Wireless Speaker System   both
# 1          226994                          Halo 3: ODST (Xbox 360)   both
# 2          226149                                 300 Bids Voucher   both
# 3          240824            Microsoft Wireless Media Desktop 1000   both
# 4          240589                 Microsoft Windows 7 Home Premium   both
# ...           ...                                              ...    ...
# 130950     232614     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both
# 130951     232606     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both
# 130952     250144     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both
# 130953     231048          Sony PlayStation 3 Slim Console (120GB)   both
# 130954     246987          Sony PlayStation 3 Slim Console (120GB)   both
#
#        stype lifestyle                                           reward  \
# ...

# %%
bracelet='[]'
df11['bracelet']=bracelet
df11
# Out:
#        auction_id                                             desc _merge  \
# 0          225354  JBL Control 2.4G On Air Wireless Speaker System   both
# 1          226994                          Halo 3: ODST (Xbox 360)   both
# 2          226149                                 300 Bids Voucher   both
# 3          240824            Microsoft Wireless Media Desktop 1000   both
# 4          240589                 Microsoft Windows 7 Home Premium   both
# ...           ...                                              ...    ...
# 130950     232614     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both
# 130951     232606     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both
# 130952     250144     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop   both
# 130953     231048          Sony PlayStation 3 Slim Console (120GB)   both
# 130954     246987          Sony PlayStation 3 Slim Console (120GB)   both
#
#        stype lifestyle                                           reward  \
# ...

# %%
df11=df11[['auction_id','stype','lifestyle','reward','desc','linked',	'bracelet']]
df11
# Out:
#        auction_id stype lifestyle  \
# 0          225354  game      game
# 1          226994  game      game
# 2          226149  game      game
# 3          240824  game      game
# 4          240589  game      game
# ...           ...   ...       ...
# 130950     232614  game      game
# 130951     232606  game      game
# 130952     250144  game      game
# 130953     231048  game      game
# 130954     246987  game      game
#
#                                                  reward  \
# 0       JBL Control 2.4G On Air Wireless Speaker System
# 1                               Halo 3: ODST (Xbox 360)
# 2                                      300 Bids Voucher
# 3                 Microsoft Wireless Media Desktop 1000
# 4                      Microsoft Windows 7 Home Premium
# ...                                                 ...
# 130950     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop
# 130951     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop
# ...

# %%
df11['braceletcopy']=df11['bracelet']
df11
# Out:
#        auction_id stype lifestyle  \
# 0          225354  game      game
# 1          226994  game      game
# 2          226149  game      game
# 3          240824  game      game
# 4          240589  game      game
# ...           ...   ...       ...
# 130950     232614  game      game
# 130951     232606  game      game
# 130952     250144  game      game
# 130953     231048  game      game
# 130954     246987  game      game
#
#                                                  reward  \
# 0       JBL Control 2.4G On Air Wireless Speaker System
# 1                               Halo 3: ODST (Xbox 360)
# 2                                      300 Bids Voucher
# 3                 Microsoft Wireless Media Desktop 1000
# 4                      Microsoft Windows 7 Home Premium
# ...                                                 ...
# 130950     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop
# 130951     Apple MacBook Pro MB991LL/A 13.3-Inch Laptop
# ...

# %%
df = pd.concat([df6, df11], ignore_index=True)

df
# Out:
#        auction_id stype lifestyle  \
# 0          244829   NaN       NaN
# 1          779670   NaN       NaN
# 2          880354   NaN       NaN
# 3          739054   NaN       NaN
# 4          180993   NaN       NaN
# ...           ...   ...       ...
# 678504     232614  game      game
# 678505     232606  game      game
# 678506     250144  game      game
# 678507     231048  game      game
# 678508     246987  game      game
#
#                                               reward  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 678504  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop
# 678505  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop
# 678506  Apple MacBook Pro MB991LL/A 13.3-Inch Laptop
# ...

# %%
df['stype'].fillna('game', inplace=True)
df['lifestyle'].fillna('game', inplace=True)
df['reward'].fillna('Wii | Nintendo Console + Wii Sports', inplace=True)
df['desc'].fillna('Wii | Nintendo Console + Wii Sports', inplace=True)
df['linked'].fillna('google.com', inplace=True)
df['bracelet'].fillna('[]', inplace=True)
df['braceletcopy'].fillna('[]', inplace=True)

# %%
df=df.drop_duplicates()
df
# Out:
#        auction_id stype lifestyle                                  reward  \
# 0          244829  game      game     Wii | Nintendo Console + Wii Sports
# 1          779670  game      game     Wii | Nintendo Console + Wii Sports
# 2          880354  game      game     Wii | Nintendo Console + Wii Sports
# 3          739054  game      game     Wii | Nintendo Console + Wii Sports
# 4          180993  game      game     Wii | Nintendo Console + Wii Sports
# ...           ...   ...       ...                                     ...
# 675619     256395  game      game                   Football Manager 2010
# 676043     247655  game      game         USBcell AA Rechargeable Battery
# 676055     252896  game      game         USBcell AA Rechargeable Battery
# 676057     253071  game      game         USBcell AA Rechargeable Battery
# 677972     230115  game      game  Digital Alcohol Tester Breath Analyzer
#
#                                           desc      linked bracelet  \
# ...

# %%
df.to_csv('newsTrain.tsv',index=False,header=False,sep="\t")
